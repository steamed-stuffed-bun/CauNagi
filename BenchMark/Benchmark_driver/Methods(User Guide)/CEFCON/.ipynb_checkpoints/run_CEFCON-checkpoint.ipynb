# %%
#step1 Command

# %%
cefcon --input_expData ./use_data/VEXAS.csv --input_priorNet ./use_data/network_human.csv --out_dir ./CEFCON_output --cuda -1 --hidden_dim 64 --output_dim 32 --heads 2 --epochs 100 --repeats 5

# %%
#step2 output data path

# %%
./CEFCON_output/driver_regulators.csv
