# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import celloracle as co
from sklearn.preprocessing import StandardScaler

# 设置绘图参数
plt.rcParams['figure.figsize'] = [6, 4]
sc.settings.verbosity = 3
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')

# 加载单细胞RNA测序数据
# 假设数据已经是AnnData格式，包含原始counts矩阵
adata = sc.read_h5ad("/disk1/cai029/Caufussion/Benchmark_driver/Dataset/all_data.h5ad")
# 基本数据预处理
print(f"数据形状: {adata.shape}")
print(f"观察值（细胞）: {adata.n_obs}, 变量（基因）: {adata.n_vars}")

# 检查数据是否包含必要的元数据
print("可用的观察列:", adata.obs.columns.tolist())
print("可用的降维信息:", list(adata.obsm.keys()))
# Out:
# /disk1/cai029/anaconda3/envs/celloracle_env/lib/python3.10/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# 数据形状: (22599, 20718)
# 观察值（细胞）: 22599, 变量（基因）: 20718
# 可用的观察列: ['NumberOfReads', 'AlignedToGenome', 'AlignedToTranscriptome', 'TranscriptomeUMIs', 'NumberOfGenes', 'CyclingScore', 'CyclingBinary', 'MutTranscripts', 'WtTranscripts', 'PredictionRF2', 'PredictionRefined', 'CellType', 'Score_HSC', 'Score_Prog', 'Score_GMP', 'Score_ProMono', 'Score_Mono', 'Score_cDC', 'Score_pDC', 'Score_earlyEry', 'Score_lateEry', 'Score_ProB', 'Score_B', 'Score_Plasma', 'Score_T', 'Score_CTL', 'Score_NK', 'sample_label', 'batch', 'NanoporeTranscripts', 'batch_origin', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'stage']
# 可用的降维信息: ['X_pca', 'X_pca_harmony']

# %%
# # 质量控制 - 过滤低质量细胞和基因
# sc.pp.filter_cells(adata, min_genes=200)  # 至少表达200个基因的细胞
# sc.pp.filter_genes(adata, min_cells=10)    # 至少在3个细胞中表达的基因

# # 归一化处理
# sc.pp.normalize_total(adata, target_sum=1e4)
# sc.pp.log1p(adata)

# # 识别高变基因
sc.pp.highly_variable_genes(adata, n_top_genes=3000)
adata = adata[:, adata.var.highly_variable]

# 降维和聚类
#sc.pp.scale(adata, max_value=10)
sc.tl.pca(adata, svd_solver='arpack')
# sc.external.pp.harmony_integrate(adata, key='batch', basis='X_pca', max_iter_harmony=20)
sc.pp.neighbors(adata, n_pcs=30, n_neighbors=30,use_rep='X_pca_harmony')
sc.tl.umap(adata)
sc.tl.leiden(adata, resolution=0.6)  # 细胞聚类
sc.pl.umap(adata, color=['CellType'], legend_loc='on data')
# Out:
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# computing PCA
#     with n_comps=50
#     finished (0:00:00)
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:16)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm)
#     'umap', UMAP parameters (adata.uns) (0:00:08)
# running Leiden clustering
#     finished: found 9 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:02)

# %%
import networkx as nx
from scipy.sparse import issparse
from scipy.stats import spearmanr
import scipy.sparse as sparse
def prepare_network(adata, prior_net, add_edges_pct=0.001, corr_cutoff=0.6, uppercase=True):
    # Ensure gene names are uppercase to match network data
    adata.var_names_make_unique()
    if uppercase:
        adata.var_names = adata.var_names.str.upper()
        prior_net['from'] = prior_net['from'].str.upper()
        prior_net['to'] = prior_net['to'].str.upper()

    # Filter the network to include only genes present in adata
    net_filtered = prior_net[prior_net['from'].isin(adata.var_names) & prior_net['to'].isin(adata.var_names)]
    net_filtered = net_filtered.drop_duplicates(subset=['from', 'to'])

    # Create a directed graph using networkx
    network = nx.from_pandas_edgelist(net_filtered, 'from', 'to', create_using=nx.DiGraph)

    # Only keep the genes that exist in both single cell data and the prior gene interaction network
    network_nodes = list(network.nodes())
    adata_filtered = adata[:, network_nodes]

    # Calculate expression correlation to add additional edges
    gene_exp = pd.DataFrame(adata_filtered.X.toarray() if sparse.issparse(adata_filtered.X) else adata_filtered.X,
                            columns=adata_filtered.var_names)
    corr_matrix = gene_exp.corr(method='spearman').abs()
    np.fill_diagonal(corr_matrix.values, 0)

    # Identify additional edges based on correlation threshold
    additional_edges = corr_matrix.stack().rename_axis(['from', 'to']).reset_index(name='weight')
    additional_edges = additional_edges[additional_edges['weight'] > corr_cutoff]

    # Limit the number of additional edges based on the percentage
    top_k = int(len(network.nodes()) * (len(network.nodes()) - 1) / 2 * add_edges_pct)
    additional_edges = additional_edges.nlargest(top_k, 'weight')[['from', 'to']]

    # Add additional edges to the network, ensuring no duplicates
    existing_edges = set(network.edges())
    new_edges = [(row['from'], row['to']) for _, row in additional_edges.iterrows() if
                 (row['from'], row['to']) not in existing_edges]
    print(f"Adding {len(new_edges)} additional edges to the network")
    network.add_edges_from(new_edges)

    return network


def get_network(adata, network, keep_self_loops=True, average_degree=10, weight_degree=True):
    """
    Further process a gene regulatory network by calculating edge weights based on Spearman correlation
    coefficients from gene expression data, removing self-loops, adjusting edge weights based on node degrees,
    filtering edges to meet an average degree threshold, and finding the largest connected subgraph.
    """
    from scipy.sparse import issparse
    from scipy.stats import spearmanr
    # Convert adata to DataFrame for easier manipulation
    gene_exp = pd.DataFrame(adata.X.toarray() if issparse(adata.X) else adata.X, columns=adata.var_names)
    # Calculate Spearman correlation coefficient for all edges in the network
    for u, v in network.edges():
        if u in gene_exp.columns and v in gene_exp.columns:
            coef, _ = spearmanr(gene_exp[u], gene_exp[v])
            network[u][v]['weight'] = abs(coef)
    print("part1 complete")
    # Remove self-loops if not allowed
    if not keep_self_loops:
        network.remove_edges_from(nx.selfloop_edges(network))

    # Adjust edge weights based on the degree of connected nodes
    for u, v, d in network.edges(data=True):
        u_degree = network.degree(u)
        v_degree = network.degree(v)
        # Adjust the weight by the average degree of the two nodes
        if weight_degree:
            d['weight'] *= (u_degree + v_degree) / 2
        # print(u, v, d['weight'])
    print("part2 complete")
    # If average_degree is specified, select edges to keep based on their adjusted weights
    if average_degree is not None:
        # Calculate the total number of edges to keep based on the average_degree
        total_edges_to_keep = int(average_degree * len(network.nodes()))
        # Sort edges by their adjusted weight in descending order and keep the top ones
        all_edges_sorted_by_weight = sorted(network.edges(data=True), key=lambda x: x[2]['weight'], reverse=True)
        edges_to_keep = all_edges_sorted_by_weight[:total_edges_to_keep]

        # Create a new graph with the selected edges and their attributes
        network_filtered = nx.DiGraph()
        for u, v, d in edges_to_keep:
            network_filtered.add_edge(u, v, **d)
        network = network_filtered
    print("part2 complete")
    # Find the largest connected subgraph
    largest_components = max(nx.weakly_connected_components(network), key=len)
    if (len(largest_components) / len(network.nodes())) < 0.5:
        print('Warning: the size of the maximal connected subgraph is less than half of the input whole graph!')
    print("part3 complete")
    network = network.subgraph(largest_components).copy()

    # Save the network to CSV if a save path is provided

    print(f"Number of nodes: {len(network.nodes)}")
    print(f"Number of edges: {len(network.edges)}")
    return network

def network_master_regulators(prior_network,adata=None, topK=50, add_edges_pct=0.01, corr_cutoff=0.6,
                                  uppercase=False, net_degree=10, weight_degree=True, save_net_path=None, out_lam=0.8, driver_union=True,
                                  ILP_lam=0.5, **kwargs):
    network = prepare_network(adata, prior_network, add_edges_pct=add_edges_pct, corr_cutoff=corr_cutoff, uppercase=uppercase)
    print("prepare_network complete!")
    network = get_network(adata, network, average_degree=net_degree, weight_degree=weight_degree)
    print("get_network complete!")
    return network

# %%
prior_net = pd.read_csv("/disk1/cai029/biosoft/CauFinder-main/resources/network/NicheNet_human.csv")
net_work = network_master_regulators(prior_network= prior_net,adata=adata)
# Out:
# Adding 69 additional edges to the network
# prepare_network complete!
# part1 complete
# part2 complete
# part2 complete
# part3 complete
# Number of nodes: 2537
# Number of edges: 27510
# get_network complete!

# %%
df_edges = nx.to_pandas_edgelist(net_work)
df_edges = df_edges[df_edges['source'] != df_edges['target']]
print(df_edges)
# Out:
#        source   target      weight
# 1         MYC   POU4F1  337.656548
# 2         MYC  RUNX1T1  290.442563
# 3         MYC     CAV1  277.284261
# 4         MYC    GATA2  265.566475
# 5         MYC      VIM  260.626321
# ...       ...      ...         ...
# 27505  COL6A2   COL1A2   12.304442
# 27506  COL6A2    LAMA4   10.406210
# 27507    RGS7      FOS   13.204857
# 27508   GNRH1      FOS   12.260766
# 27509   ENPEP    VCAM1   11.159542
#
# [27383 rows x 3 columns]

# %%
# 使用扩散映射或PAGA推断发育轨迹
sc.tl.diffmap(adata)  # 扩散映射
sc.tl.paga(adata)     # PAGA图
sc.pl.paga(adata, plot=False)  # 可视化PAGA结果

# 选择根细胞（通常是最不成熟的细胞类型或健康对照）
# 这里假设簇0是起始点，根据您的数据调整
root_cell = np.where(adata.obs['CellType'] == 'HSC')[0][0]

# 计算扩散伪时间
adata.uns['iroot'] = root_cell
sc.tl.dpt(adata)  # 扩散伪时间

# 可视化伪时间
sc.pl.umap(adata, color=['dpt_pseudotime'], cmap='viridis')
plt.savefig("./1.png")
# Out:
# computing Diffusion Maps using n_comps=15(=n_dcs)
# computing transitions
#     finished (0:00:00)
#     eigenvalues of transition matrix
#     [1.         0.99146    0.98126304 0.9777129  0.9671842  0.95723116
#      0.94598854 0.93412745 0.93005604 0.9194282  0.89880025 0.8902121
#      0.8845486  0.87921613 0.86714876]
#     finished: added
#     'X_diffmap', diffmap coordinates (adata.obsm)
#     'diffmap_evals', eigenvalues of transition matrix (adata.uns) (0:00:01)
# running PAGA
#     finished: added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns) (0:00:00)
# --> added 'pos', the PAGA positions (adata.uns['paga'])
# computing Diffusion Pseudotime using n_dcs=10
#     finished: added
#     'dpt_pseudotime', the pseudotime (adata.obs) (0:00:00)

# %%
# net_work = df_edges.rename(columns={'source': 'TF', 'weight': 'importance'})
# 1. 创建pivot表,将source-target转换为矩阵格式  
base_grn = df_edges.pivot_table(  
    index='target',  # 靶基因作为行  
    columns='source',  # TF作为列  
    values='weight',  # 使用weight值  
    fill_value=0  # 没有连接的填充0  
)  
  
# 2. 转换为二值矩阵(如果需要)  
# CellOracle通常使用0/1表示是否存在调控关系  
# 您可以设置阈值将weight转换为0/1  
threshold = 10  # 根据您的数据调整  
base_grn_binary = (base_grn > threshold).astype(int)  
  
# 3. 添加必需的列  
base_grn_binary = base_grn_binary.reset_index()  
base_grn_binary.insert(0, 'peak_id', 'custom_peak_' + base_grn_binary.index.astype(str))  
base_grn_binary = base_grn_binary.rename(columns={'target': 'gene_short_name'})

# %%
# 创建Oracle对象并导入数据
oracle = co.Oracle()
oracle.import_anndata_as_raw_count(adata=adata,
                                  cluster_column_name="CellType",  # 聚类列名
                                  embedding_name="X_pca_harmony")       # 降维坐标名称

# 导入TF信息
oracle.import_TF_data(TF_info_matrix=base_grn_binary)

# KNN插值改善数据连续性
oracle.perform_PCA()
n_comps = min(np.where(np.diff(np.diff(np.cumsum(oracle.pca.explained_variance_ratio_)) > 0.002))[0][0], 50)
k = int(0.025 * oracle.adata.shape[0])  # 自动选择k值
oracle.knn_imputation(n_pca_dims=n_comps, k=k, balanced=True, 
                      b_sight=k*8, b_maxl=k*4, n_jobs=4)

# 构建细胞类型特异性GRN
links = oracle.get_links(cluster_name_for_GRN_unit="CellType", 
                         alpha=10, verbose_level=1)

# 过滤不可靠的连接
links.filter_links()
# Out:
# WARNING: adata.X seems to be already log-transformed.
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# # 加载基础GRN（这里使用内置的人类启动子base GRN）
# base_GRN = co.data.load_human_promoter_base_GRN()
# print(f"基础GRN大小: {base_GRN.shape}")

# # 创建Oracle对象并导入数据
# oracle = co.Oracle()
# oracle.import_anndata_as_raw_count(adata=adata,
#                                   cluster_column_name="CellType",  # 聚类列名
#                                   embedding_name="X_pca_harmony")       # 降维坐标名称

# # 导入TF信息
# oracle.import_TF_data(TF_info_matrix=base_GRN)

# # KNN插值改善数据连续性
# oracle.perform_PCA()
# n_comps = min(np.where(np.diff(np.diff(np.cumsum(oracle.pca.explained_variance_ratio_)) > 0.002))[0][0], 50)
# k = int(0.025 * oracle.adata.shape[0])  # 自动选择k值
# oracle.knn_imputation(n_pca_dims=n_comps, k=k, balanced=True, 
#                       b_sight=k*8, b_maxl=k*4, n_jobs=4)

# # 构建细胞类型特异性GRN
# links = oracle.get_links(cluster_name_for_GRN_unit="CellType", 
#                          alpha=10, verbose_level=1)

# # 过滤不可靠的连接
# links.filter_links()
# Out:
# Loading prebuilt promoter base-GRN. Version: hg19_gimmemotifsv5_fpr2
# 基础GRN大小: (37003, 1096)
# WARNING: adata.X seems to be already log-transformed.
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# 准备扰动模拟
oracle.get_cluster_specific_TFdict_from_Links(links_object=links)
oracle.fit_GRN_for_simulation(alpha=10, use_cluster_specific_TFdict=True)

# 获取所有转录因子列表
all_tfs_in_base_grn = base_grn_binary.columns[2:].tolist()  # 跳过'peak_id'和'gene_short_name'
print(f"基础GRN中定义的转录因子总数: {len(all_tfs_in_base_grn)}")

# 2. 从您的单细胞数据（adata）中获取所有实际检测到的基因
all_genes_in_expression_data = adata.var_names.tolist()
print(f"表达矩阵中检测到的基因总数: {len(all_genes_in_expression_data)}")

# 3. 取交集，得到可用于模拟的有效TF列表
available_tfs = list(set(all_tfs_in_base_grn) & set(all_genes_in_expression_data) & set(oracle.active_regulatory_genes))
available_tfs.sort()  # 排序方便查看
print(f"可用于扰动模拟的有效转录因子数量: {len(available_tfs)}")
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# 基础GRN中定义的转录因子总数: 847
# 表达矩阵中检测到的基因总数: 3000
# 可用于扰动模拟的有效转录因子数量: 742

# %%
# # 1. 在循环外执行一次性的、与TF无关的计算
# print("正在计算基础的细胞转移概率...")
#  # 显著调小参数
# print("基础计算完成。")

def reduce_embedding_dimension(oracle, target_dim=10):
    """降低嵌入维度以减少内存使用"""
    from sklearn.decomposition import PCA
    
    original_embedding = oracle.adata.obsm[oracle.embedding_name]
    
    # 使用PCA降维
    pca = PCA(n_components=target_dim)
    reduced_embedding = pca.fit_transform(original_embedding)
    
    # 更新嵌入
    oracle.adata.obsm[oracle.embedding_name] = reduced_embedding
    oracle.embedding = reduced_embedding
    
    print(f"嵌入维度从 {original_embedding.shape[1]} 降至 {target_dim}")
    return oracle

# 降低维度
print("降低嵌入维度...")
oracle_reduced = reduce_embedding_dimension(oracle, target_dim=10)

#随机选择一部分细胞进行分析  
import numpy as np  
np.random.seed(123)  
n_cells_subsample = 10000  
cell_idx_use = np.random.choice(len(oracle.adata), n_cells_subsample, replace=False)
# Out:
# 降低嵌入维度...
# 嵌入维度从 50 降至 10

# %%
# 计算扰动分数（与伪时间轨迹比较）
from celloracle.applications import Gradient_calculator, Oracle_development_module
import numpy as np  
if oracle.embedding.shape[1] != 2:  
    print(f"Warning: Oracle embedding has {oracle.embedding.shape[1]} dimensions")  
    print("Extracting first 2 dimensions or computing UMAP...")  
      
    # 选项A: 使用前两个维度  
    oracle.embedding = oracle.embedding[:, :2]  
    oracle.adata.obsm[oracle.embedding_name] = oracle.embedding.copy()  
# 计算发育梯度
gradient = Gradient_calculator(oracle_object=oracle, pseudotime_key="dpt_pseudotime")
n_grid = 40
gradient.calculate_p_mass(smooth=0.8, n_grid=n_grid, n_neighbors=200)
gradient.calculate_mass_filter(min_mass=7.4, plot=True)
gradient.transfer_data_into_grid(args={"method": "polynomial", "n_poly": 3})
gradient.calculate_gradient()

# %%
from celloracle.applications import Oracle_development_module, Oracle_systematic_analysis_helper  
perturbation_results = {}
import time
for tf in available_tfs:  # 为演示只分析前20个TF，实际可分析全部
    try:  
        print("==========Use tf is :",tf,"=============")
        # 模拟TF敲低（表达量设为0）
        start_time = time.time()
        oracle.simulate_shift(perturb_condition={tf: 0.0}, n_propagation=3)
        oracle.estimate_transition_prob(n_neighbors=100,
                                        knn_random=True, 
                                        sampled_fraction=0.2, 
                                        calculate_randomized=True,
                                        cell_idx_use=cell_idx_use
                                       ) 
        oracle.calculate_embedding_shift(sigma_corr=0.05)
        perturbation_results[tf] = oracle.delta_embedding.copy()
        end_time = time.time()
        execution_time = end_time - start_time
        print(f"已完成 {tf} 的扰动模拟",f"执行时间：{execution_time} 秒")
        
    except ValueError as e:
        print(f"跳过 {tf}: {str(e)}")
# Out:
# ==========Use tf is : A2M =============
# 已完成 A2M 的扰动模拟 执行时间：67.23897075653076 秒
# ==========Use tf is : ABCA1 =============
# 已完成 ABCA1 的扰动模拟 执行时间：67.47422575950623 秒
# ==========Use tf is : ABCB1 =============
# 已完成 ABCB1 的扰动模拟 执行时间：67.69273948669434 秒
# ==========Use tf is : ABCC2 =============
# 已完成 ABCC2 的扰动模拟 执行时间：67.26582956314087 秒
# ==========Use tf is : ABI2 =============
# 已完成 ABI2 的扰动模拟 执行时间：67.72068929672241 秒
# ==========Use tf is : ABI3 =============
# 已完成 ABI3 的扰动模拟 执行时间：67.08382320404053 秒
# ==========Use tf is : ABLIM1 =============
# 已完成 ABLIM1 的扰动模拟 执行时间：67.70006465911865 秒
# ==========Use tf is : ACVR2A =============
# 已完成 ACVR2A 的扰动模拟 执行时间：67.73894381523132 秒
# ==========Use tf is : ADM =============
# 已完成 ADM 的扰动模拟 执行时间：67.68471932411194 秒
# ==========Use tf is : AFAP1 =============
# 已完成 AFAP1 的扰动模拟 执行时间：68.2967803478241 秒
# ==========Use tf is : AFDN =============
# 已完成 AFDN 的扰动模拟 执行时间：69.74935388565063 秒
# ==========Use tf is : AGL =============
# 已完成 AGL 的扰动模拟 执行时间：67.50362944602966 秒
# ==========Use tf is : AHNAK =============
# 已完成 AHNAK 的扰动模拟 执行时间：67.39345407485962 秒
# ==========Use tf is : AHSP =============
# 已完成 AHSP 的扰动模拟 执行时间：67.78026461601257 秒
# ==========Use tf is : AIM2 =============
# 已完成 AIM2 的扰动模拟 执行时间：67.21615386009216 秒
# ==========Use tf is : AKAP12 =============
# 已完成 AKAP12 的扰动模拟 执行时间：73.41616177558899 秒
# ==========Use tf is : AKAP2 =============
# 已完成 AKAP2 的扰动模拟 执行时间：67.79704761505127 秒
# ==========Use tf is : ALAS2 =============
# 已完成 ALAS2 的扰动模拟 执行时间：67.55090594291687 秒
# ==========Use tf is : ALMS1 =============
# 已完成 ALMS1 的扰动模拟 执行时间：67.63091564178467 秒
# ==========Use tf is : ALOX5 =============
# 已完成 ALOX5 的扰动模拟 执行时间：67.72574162483215 秒
# ==========Use tf is : AMMECR1 =============
# 已完成 AMMECR1 的扰动模拟 执行时间：67.10940623283386 秒
# ==========Use tf is : ANKH =============
# 已完成 ANKH 的扰动模拟 执行时间：67.7346031665802 秒
# ==========Use tf is : ANXA1 =============
# 已完成 ANXA1 的扰动模拟 执行时间：68.07709836959839 秒
# ==========Use tf is : APBB1 =============
# 已完成 APBB1 的扰动模拟 执行时间：67.282559633255 秒
# ==========Use tf is : APC =============
# 已完成 APC 的扰动模拟 执行时间：67.75983572006226 秒
# ==========Use tf is : APOC1 =============
# 已完成 APOC1 的扰动模拟 执行时间：67.2894868850708 秒
# ==========Use tf is : APOE =============
# 已完成 APOE 的扰动模拟 执行时间：68.38702726364136 秒
# ==========Use tf is : AQP9 =============
# 已完成 AQP9 的扰动模拟 执行时间：67.68614459037781 秒
# ==========Use tf is : AREG =============
# 已完成 AREG 的扰动模拟 执行时间：67.78721833229065 秒
# ==========Use tf is : ARHGAP21 =============
# 已完成 ARHGAP21 的扰动模拟 执行时间：67.2899260520935 秒
# ==========Use tf is : ARHGAP22 =============
# 已完成 ARHGAP22 的扰动模拟 执行时间：67.79079818725586 秒
# ==========Use tf is : ARHGAP24 =============
# 已完成 ARHGAP24 的扰动模拟 执行时间：70.14186239242554 秒
# ==========Use tf is : ARID4A =============
# 已完成 ARID4A 的扰动模拟 执行时间：90.85566067695618 秒
# ==========Use tf is : ARID5B =============
# 已完成 ARID5B 的扰动模拟 执行时间：70.4801414012909 秒
# ==========Use tf is : ARNTL =============
# 已完成 ARNTL 的扰动模拟 执行时间：71.47736239433289 秒
# ==========Use tf is : ASPM =============
# 已完成 ASPM 的扰动模拟 执行时间：86.39082622528076 秒
# ==========Use tf is : ATF1 =============
# 已完成 ATF1 的扰动模拟 执行时间：79.47407579421997 秒
# ==========Use tf is : ATF3 =============
# 已完成 ATF3 的扰动模拟 执行时间：68.43115711212158 秒
# ==========Use tf is : ATM =============
# 已完成 ATM 的扰动模拟 执行时间：67.53045725822449 秒
# ==========Use tf is : ATP2B1 =============
# 已完成 ATP2B1 的扰动模拟 执行时间：67.65196895599365 秒
# ==========Use tf is : AXIN2 =============
# 已完成 AXIN2 的扰动模拟 执行时间：67.47877335548401 秒
# ==========Use tf is : AZU1 =============
# 已完成 AZU1 的扰动模拟 执行时间：67.29567909240723 秒
# ==========Use tf is : B2M =============
# 已完成 B2M 的扰动模拟 执行时间：67.91620635986328 秒
# ==========Use tf is : BACH2 =============
# 已完成 BACH2 的扰动模拟 执行时间：67.30509209632874 秒
# ==========Use tf is : BAG2 =============
# 已完成 BAG2 的扰动模拟 执行时间：67.92020297050476 秒
# ==========Use tf is : BANK1 =============
# 已完成 BANK1 的扰动模拟 执行时间：67.40373611450195 秒
# ==========Use tf is : BATF =============
# 已完成 BATF 的扰动模拟 执行时间：68.04130291938782 秒
# ==========Use tf is : BATF3 =============
# 已完成 BATF3 的扰动模拟 执行时间：67.51341414451599 秒
# ==========Use tf is : BCL10 =============
# 已完成 BCL10 的扰动模拟 执行时间：67.39548707008362 秒
# ==========Use tf is : BCL11B =============
# 已完成 BCL11B 的扰动模拟 执行时间：67.55389142036438 秒
# ==========Use tf is : BCL2 =============
# 已完成 BCL2 的扰动模拟 执行时间：67.40646195411682 秒
# ==========Use tf is : BCL2A1 =============
# 已完成 BCL2A1 的扰动模拟 执行时间：67.20479011535645 秒
# ==========Use tf is : BCL2L11 =============
# 已完成 BCL2L11 的扰动模拟 执行时间：67.50566506385803 秒
# ==========Use tf is : BCL6 =============
# 已完成 BCL6 的扰动模拟 执行时间：67.73460245132446 秒
# ==========Use tf is : BCL9L =============
# 已完成 BCL9L 的扰动模拟 执行时间：67.26244926452637 秒
# ==========Use tf is : BCOR =============
# 已完成 BCOR 的扰动模拟 执行时间：67.61002492904663 秒
# ==========Use tf is : BGLAP =============
# 已完成 BGLAP 的扰动模拟 执行时间：67.18606305122375 秒
# ==========Use tf is : BIN1 =============
# 已完成 BIN1 的扰动模拟 执行时间：68.16099977493286 秒
# ==========Use tf is : BIRC3 =============
# 已完成 BIRC3 的扰动模拟 执行时间：67.47686219215393 秒
# ==========Use tf is : BLK =============
# 已完成 BLK 的扰动模拟 执行时间：74.09677290916443 秒
# ==========Use tf is : BMF =============
# 已完成 BMF 的扰动模拟 执行时间：80.90746569633484 秒
# ==========Use tf is : BMPR2 =============
# 已完成 BMPR2 的扰动模拟 执行时间：79.47565126419067 秒
# ==========Use tf is : BUB1B =============
# 已完成 BUB1B 的扰动模拟 执行时间：78.77132034301758 秒
# ==========Use tf is : C15orf40 =============
# 已完成 C15orf40 的扰动模拟 执行时间：80.13206839561462 秒
# ==========Use tf is : C17orf80 =============
# 已完成 C17orf80 的扰动模拟 执行时间：79.50019001960754 秒
# ==========Use tf is : C1QA =============
# 已完成 C1QA 的扰动模拟 执行时间：79.88623905181885 秒
# ==========Use tf is : C1QC =============
# 已完成 C1QC 的扰动模拟 执行时间：78.35406112670898 秒
# ==========Use tf is : C3AR1 =============
# 已完成 C3AR1 的扰动模拟 执行时间：76.5993721485138 秒
# ==========Use tf is : C5AR1 =============
# 已完成 C5AR1 的扰动模拟 执行时间：80.57133102416992 秒
# ==========Use tf is : CA1 =============
# 已完成 CA1 的扰动模拟 执行时间：74.95161581039429 秒
# ==========Use tf is : CA2 =============
# 已完成 CA2 的扰动模拟 执行时间：71.61912298202515 秒
# ==========Use tf is : CACNA1A =============
# 已完成 CACNA1A 的扰动模拟 执行时间：100.95910787582397 秒
# ==========Use tf is : CADM1 =============
# 已完成 CADM1 的扰动模拟 执行时间：69.27097034454346 秒
# ==========Use tf is : CAMK2D =============
# 已完成 CAMK2D 的扰动模拟 执行时间：71.52994656562805 秒
# ==========Use tf is : CAMK4 =============
# 已完成 CAMK4 的扰动模拟 执行时间：74.69559383392334 秒
# ==========Use tf is : CAMP =============
# 已完成 CAMP 的扰动模拟 执行时间：95.56056141853333 秒
# ==========Use tf is : CASP8 =============
# 已完成 CASP8 的扰动模拟 执行时间：68.45428800582886 秒
# ==========Use tf is : CAV1 =============
# 已完成 CAV1 的扰动模拟 执行时间：71.72879886627197 秒
# ==========Use tf is : CAVIN1 =============
# 已完成 CAVIN1 的扰动模拟 执行时间：76.52445840835571 秒
# ==========Use tf is : CCL5 =============
# 已完成 CCL5 的扰动模拟 执行时间：84.21015429496765 秒
# ==========Use tf is : CCNF =============
# 已完成 CCNF 的扰动模拟 执行时间：68.01146912574768 秒
# ==========Use tf is : CCR1 =============
# 已完成 CCR1 的扰动模拟 执行时间：69.3061876296997 秒
# ==========Use tf is : CCR5 =============
# 已完成 CCR5 的扰动模拟 执行时间：67.66430687904358 秒
# ==========Use tf is : CCR6 =============
# 已完成 CCR6 的扰动模拟 执行时间：69.11677861213684 秒
# ==========Use tf is : CCR7 =============
# 已完成 CCR7 的扰动模拟 执行时间：67.6850118637085 秒
# ==========Use tf is : CD14 =============
# 已完成 CD14 的扰动模拟 执行时间：67.65590238571167 秒
# ==========Use tf is : CD160 =============
# 已完成 CD160 的扰动模拟 执行时间：67.73274779319763 秒
# ==========Use tf is : CD1D =============
# 已完成 CD1D 的扰动模拟 执行时间：67.25512933731079 秒
# ==========Use tf is : CD2 =============
# 已完成 CD2 的扰动模拟 执行时间：68.11611676216125 秒
# ==========Use tf is : CD22 =============
# 已完成 CD22 的扰动模拟 执行时间：67.7560646533966 秒
# ==========Use tf is : CD24 =============
# 已完成 CD24 的扰动模拟 执行时间：67.41576671600342 秒
# ==========Use tf is : CD247 =============
# 已完成 CD247 的扰动模拟 执行时间：67.61360168457031 秒
# ==========Use tf is : CD274 =============
# 已完成 CD274 的扰动模拟 执行时间：67.2667989730835 秒
# ==========Use tf is : CD28 =============
# 已完成 CD28 的扰动模拟 执行时间：68.44442868232727 秒
# ==========Use tf is : CD34 =============
# 已完成 CD34 的扰动模拟 执行时间：67.88416457176208 秒
# ==========Use tf is : CD36 =============
# 已完成 CD36 的扰动模拟 执行时间：61.025742530822754 秒
# ==========Use tf is : CD3D =============
# 已完成 CD3D 的扰动模拟 执行时间：58.927470684051514 秒
# ==========Use tf is : CD3E =============
# 已完成 CD3E 的扰动模拟 执行时间：59.23698401451111 秒
# ==========Use tf is : CD3G =============
# 已完成 CD3G 的扰动模拟 执行时间：59.72666645050049 秒
# ==========Use tf is : CD40LG =============
# 已完成 CD40LG 的扰动模拟 执行时间：65.17881774902344 秒
# ==========Use tf is : CD47 =============
# 已完成 CD47 的扰动模拟 执行时间：58.940690994262695 秒
# ==========Use tf is : CD48 =============
# 已完成 CD48 的扰动模拟 执行时间：59.59488487243652 秒
# ==========Use tf is : CD5 =============
# 已完成 CD5 的扰动模拟 执行时间：59.62925362586975 秒
# ==========Use tf is : CD6 =============
# 已完成 CD6 的扰动模拟 执行时间：59.18724775314331 秒
# ==========Use tf is : CD7 =============
# 已完成 CD7 的扰动模拟 执行时间：78.67388558387756 秒
# ==========Use tf is : CD74 =============
# 已完成 CD74 的扰动模拟 执行时间：68.08965373039246 秒
# ==========Use tf is : CD79A =============
# 已完成 CD79A 的扰动模拟 执行时间：60.72451066970825 秒
# ==========Use tf is : CD79B =============
# 已完成 CD79B 的扰动模拟 执行时间：59.15703225135803 秒
# ==========Use tf is : CD86 =============
# 已完成 CD86 的扰动模拟 执行时间：61.74688911437988 秒
# ==========Use tf is : CD8A =============
# 已完成 CD8A 的扰动模拟 执行时间：66.34994673728943 秒
# ==========Use tf is : CD8B =============
# 已完成 CD8B 的扰动模拟 执行时间：59.11119890213013 秒
# ==========Use tf is : CDC42EP3 =============
# 已完成 CDC42EP3 的扰动模拟 执行时间：59.515931606292725 秒
# ==========Use tf is : CDK5R1 =============
# 已完成 CDK5R1 的扰动模拟 执行时间：59.257222175598145 秒
# ==========Use tf is : CDKN1A =============
# 已完成 CDKN1A 的扰动模拟 执行时间：59.27851867675781 秒
# ==========Use tf is : CDKN2D =============
# 已完成 CDKN2D 的扰动模拟 执行时间：58.89746570587158 秒
# ==========Use tf is : CEBPD =============
# 已完成 CEBPD 的扰动模拟 执行时间：59.12683320045471 秒
# ==========Use tf is : CENPE =============
# 已完成 CENPE 的扰动模拟 执行时间：59.023319244384766 秒
# ==========Use tf is : CENPF =============
# 已完成 CENPF 的扰动模拟 执行时间：59.16259169578552 秒
# ==========Use tf is : CEP120 =============
# 已完成 CEP120 的扰动模拟 执行时间：59.266146183013916 秒
# ==========Use tf is : CEP128 =============
# 已完成 CEP128 的扰动模拟 执行时间：59.81310558319092 秒
# ==========Use tf is : CEP135 =============
# 已完成 CEP135 的扰动模拟 执行时间：59.4122416973114 秒
# ==========Use tf is : CEP290 =============
# 已完成 CEP290 的扰动模拟 执行时间：59.08276319503784 秒
# ==========Use tf is : CEP70 =============
# 已完成 CEP70 的扰动模拟 执行时间：59.163652181625366 秒
# ==========Use tf is : CES1 =============
# 已完成 CES1 的扰动模拟 执行时间：58.94430732727051 秒
# ==========Use tf is : CFD =============
# 已完成 CFD 的扰动模拟 执行时间：59.22488474845886 秒
# ==========Use tf is : CHD7 =============
# 已完成 CHD7 的扰动模拟 执行时间：59.07728290557861 秒
# ==========Use tf is : CHI3L2 =============
# 已完成 CHI3L2 的扰动模拟 执行时间：59.11020874977112 秒
# ==========Use tf is : CHIC2 =============
# 已完成 CHIC2 的扰动模拟 执行时间：59.117392778396606 秒
# ==========Use tf is : CHRNA7 =============
# 已完成 CHRNA7 的扰动模拟 执行时间：59.412964820861816 秒
# ==========Use tf is : CHST15 =============
# 已完成 CHST15 的扰动模拟 执行时间：59.65160775184631 秒
# ==========Use tf is : CITED2 =============
# 已完成 CITED2 的扰动模拟 执行时间：65.91427898406982 秒
# ==========Use tf is : CKB =============
# 已完成 CKB 的扰动模拟 执行时间：73.02707695960999 秒
# ==========Use tf is : CLDN3 =============
# 已完成 CLDN3 的扰动模拟 执行时间：73.67079067230225 秒
# ==========Use tf is : CLEC4A =============
# 已完成 CLEC4A 的扰动模拟 执行时间：73.51812148094177 秒
# ==========Use tf is : CLEC7A =============
# 已完成 CLEC7A 的扰动模拟 执行时间：72.51816296577454 秒
# ==========Use tf is : CLIC2 =============
# 已完成 CLIC2 的扰动模拟 执行时间：74.88555335998535 秒
# ==========Use tf is : CLOCK =============
# 已完成 CLOCK 的扰动模拟 执行时间：73.08972144126892 秒
# ==========Use tf is : CMC1 =============
# 已完成 CMC1 的扰动模拟 执行时间：72.89539837837219 秒
# ==========Use tf is : COL1A2 =============
# 已完成 COL1A2 的扰动模拟 执行时间：73.63895988464355 秒
# ==========Use tf is : COL4A3 =============
# 已完成 COL4A3 的扰动模拟 执行时间：74.19381475448608 秒
# ==========Use tf is : COMMD3 =============
# 已完成 COMMD3 的扰动模拟 执行时间：72.81382870674133 秒
# ==========Use tf is : CPEB4 =============
# 已完成 CPEB4 的扰动模拟 执行时间：73.85349559783936 秒
# ==========Use tf is : CPNE5 =============
# 已完成 CPNE5 的扰动模拟 执行时间：73.98242998123169 秒
# ==========Use tf is : CPVL =============
# 已完成 CPVL 的扰动模拟 执行时间：72.93235659599304 秒
# ==========Use tf is : CREB3 =============
# 已完成 CREB3 的扰动模拟 执行时间：61.91781258583069 秒
# ==========Use tf is : CREB5 =============
# 已完成 CREB5 的扰动模拟 执行时间：58.688671827316284 秒
# ==========Use tf is : CREBL2 =============
# 已完成 CREBL2 的扰动模拟 执行时间：72.26750206947327 秒
# ==========Use tf is : CREM =============
# 已完成 CREM 的扰动模拟 执行时间：73.0783097743988 秒
# ==========Use tf is : CRY1 =============
# 已完成 CRY1 的扰动模拟 执行时间：74.22988724708557 秒
# ==========Use tf is : CSF1 =============
# 已完成 CSF1 的扰动模拟 执行时间：73.43372702598572 秒
# ==========Use tf is : CSF1R =============
# 已完成 CSF1R 的扰动模拟 执行时间：73.09556293487549 秒
# ==========Use tf is : CSNK1G1 =============
# 已完成 CSNK1G1 的扰动模拟 执行时间：74.17837071418762 秒
# ==========Use tf is : CST3 =============
# 已完成 CST3 的扰动模拟 执行时间：75.2336072921753 秒
# ==========Use tf is : CSTA =============
# 已完成 CSTA 的扰动模拟 执行时间：73.30920505523682 秒
# ==========Use tf is : CTGF =============
# 已完成 CTGF 的扰动模拟 执行时间：74.23603391647339 秒
# ==========Use tf is : CTLA4 =============
# 已完成 CTLA4 的扰动模拟 执行时间：75.25194144248962 秒
# ==========Use tf is : CTSG =============
# 已完成 CTSG 的扰动模拟 执行时间：73.26559567451477 秒
# ==========Use tf is : CTSH =============
# 已完成 CTSH 的扰动模拟 执行时间：73.02355813980103 秒
# ==========Use tf is : CTSL =============
# 已完成 CTSL 的扰动模拟 执行时间：74.68211340904236 秒
# ==========Use tf is : CTSS =============
# 已完成 CTSS 的扰动模拟 执行时间：73.68408799171448 秒
# ==========Use tf is : CX3CR1 =============
# 已完成 CX3CR1 的扰动模拟 执行时间：58.89399266242981 秒
# ==========Use tf is : CXADR =============
# 已完成 CXADR 的扰动模拟 执行时间：58.88230800628662 秒
# ==========Use tf is : CXCL10 =============
# 已完成 CXCL10 的扰动模拟 执行时间：58.985806465148926 秒
# ==========Use tf is : CXCL12 =============
# 已完成 CXCL12 的扰动模拟 执行时间：59.50648880004883 秒
# ==========Use tf is : CXCL16 =============
# 已完成 CXCL16 的扰动模拟 执行时间：59.30884408950806 秒
# ==========Use tf is : CXCL2 =============
# 已完成 CXCL2 的扰动模拟 执行时间：58.85352945327759 秒
# ==========Use tf is : CXCL3 =============
# 已完成 CXCL3 的扰动模拟 执行时间：59.357362031936646 秒
# ==========Use tf is : CXCL8 =============
# 已完成 CXCL8 的扰动模拟 执行时间：58.98511743545532 秒
# ==========Use tf is : CYBB =============
# 已完成 CYBB 的扰动模拟 执行时间：59.130223512649536 秒
# ==========Use tf is : CYFIP2 =============
# 已完成 CYFIP2 的扰动模拟 执行时间：59.221307039260864 秒
# ==========Use tf is : CYLD =============
# 已完成 CYLD 的扰动模拟 执行时间：58.89923405647278 秒
# ==========Use tf is : CYP1B1 =============
# 已完成 CYP1B1 的扰动模拟 执行时间：59.83022618293762 秒
# ==========Use tf is : CYP7B1 =============
# 已完成 CYP7B1 的扰动模拟 执行时间：58.570857763290405 秒
# ==========Use tf is : CYSLTR2 =============
# 已完成 CYSLTR2 的扰动模拟 执行时间：59.45050287246704 秒
# ==========Use tf is : DACH1 =============
# 已完成 DACH1 的扰动模拟 执行时间：59.14565706253052 秒
# ==========Use tf is : DCN =============
# 已完成 DCN 的扰动模拟 执行时间：59.212316036224365 秒
# ==========Use tf is : DDIT3 =============
# 已完成 DDIT3 的扰动模拟 执行时间：59.32900524139404 秒
# ==========Use tf is : DDIT4L =============
# 已完成 DDIT4L 的扰动模拟 执行时间：59.415897846221924 秒
# ==========Use tf is : DDX58 =============
# 已完成 DDX58 的扰动模拟 执行时间：58.94677996635437 秒
# ==========Use tf is : DEFB1 =============
# 已完成 DEFB1 的扰动模拟 执行时间：59.109925508499146 秒
# ==========Use tf is : DHRS9 =============
# 已完成 DHRS9 的扰动模拟 执行时间：59.244789123535156 秒
# ==========Use tf is : DKK1 =============
# 已完成 DKK1 的扰动模拟 执行时间：58.70045471191406 秒
# ==========Use tf is : DLGAP5 =============
# 已完成 DLGAP5 的扰动模拟 执行时间：59.158055782318115 秒
# ==========Use tf is : DLK1 =============
# 已完成 DLK1 的扰动模拟 执行时间：58.76135754585266 秒
# ==========Use tf is : DMTN =============
# 已完成 DMTN 的扰动模拟 执行时间：59.165546894073486 秒
# ==========Use tf is : DNAH8 =============
# 已完成 DNAH8 的扰动模拟 执行时间：58.82718634605408 秒
# ==========Use tf is : DNAJB1 =============
# 已完成 DNAJB1 的扰动模拟 执行时间：59.292388677597046 秒
# ==========Use tf is : DNAJB9 =============
# 已完成 DNAJB9 的扰动模拟 执行时间：59.07666206359863 秒
# ==========Use tf is : DNTT =============
# 已完成 DNTT 的扰动模拟 执行时间：59.09309911727905 秒
# ==========Use tf is : DUSP6 =============
# 已完成 DUSP6 的扰动模拟 执行时间：59.26594400405884 秒
# ==========Use tf is : DYNC2H1 =============
# 已完成 DYNC2H1 的扰动模拟 执行时间：58.734389781951904 秒
# ==========Use tf is : DYRK2 =============
# 已完成 DYRK2 的扰动模拟 执行时间：59.278571367263794 秒
# ==========Use tf is : E2F7 =============
# 已完成 E2F7 的扰动模拟 执行时间：58.912394285202026 秒
# ==========Use tf is : EAF1 =============
# 已完成 EAF1 的扰动模拟 执行时间：58.73553657531738 秒
# ==========Use tf is : EBF1 =============
# 已完成 EBF1 的扰动模拟 执行时间：58.88990259170532 秒
# ==========Use tf is : EBF3 =============
# 已完成 EBF3 的扰动模拟 执行时间：59.042165756225586 秒
# ==========Use tf is : EFHC1 =============
# 已完成 EFHC1 的扰动模拟 执行时间：59.4085431098938 秒
# ==========Use tf is : EGR1 =============
# 已完成 EGR1 的扰动模拟 执行时间：59.576074838638306 秒
# ==========Use tf is : EGR2 =============
# 已完成 EGR2 的扰动模拟 执行时间：58.86732363700867 秒
# ==========Use tf is : EGR3 =============
# 已完成 EGR3 的扰动模拟 执行时间：59.330649852752686 秒
# ==========Use tf is : ELANE =============
# 已完成 ELANE 的扰动模拟 执行时间：59.94001746177673 秒
# ==========Use tf is : ELAVL4 =============
# 已完成 ELAVL4 的扰动模拟 执行时间：59.002355337142944 秒
# ==========Use tf is : ELL2 =============
# 已完成 ELL2 的扰动模拟 执行时间：59.4856390953064 秒
# ==========Use tf is : EMP1 =============
# 已完成 EMP1 的扰动模拟 执行时间：58.820045948028564 秒
# ==========Use tf is : EN1 =============
# 已完成 EN1 的扰动模拟 执行时间：59.29354810714722 秒
# ==========Use tf is : ENAH =============
# 已完成 ENAH 的扰动模拟 执行时间：59.4556245803833 秒
# ==========Use tf is : EOMES =============
# 已完成 EOMES 的扰动模拟 执行时间：59.506556272506714 秒
# ==========Use tf is : EPAS1 =============
# 已完成 EPAS1 的扰动模拟 执行时间：59.36755156517029 秒
# ==========Use tf is : EPHA2 =============
# 已完成 EPHA2 的扰动模拟 执行时间：59.27475547790527 秒
# ==========Use tf is : EPHA4 =============
# 已完成 EPHA4 的扰动模拟 执行时间：59.487993478775024 秒
# ==========Use tf is : EPHB2 =============
# 已完成 EPHB2 的扰动模拟 执行时间：59.03189468383789 秒
# ==========Use tf is : ERCC4 =============
# 已完成 ERCC4 的扰动模拟 执行时间：59.14813184738159 秒
# ==========Use tf is : ERCC6 =============
# 已完成 ERCC6 的扰动模拟 执行时间：59.08646273612976 秒
# ==========Use tf is : EREG =============
# 已完成 EREG 的扰动模拟 执行时间：59.51091527938843 秒
# ==========Use tf is : ETS1 =============
# 已完成 ETS1 的扰动模拟 执行时间：59.27462887763977 秒
# ==========Use tf is : ETV1 =============
# 已完成 ETV1 的扰动模拟 执行时间：59.850319623947144 秒
# ==========Use tf is : EVI5 =============
# 已完成 EVI5 的扰动模拟 执行时间：58.76718783378601 秒
# ==========Use tf is : EXD2 =============
# 已完成 EXD2 的扰动模拟 执行时间：59.06638526916504 秒
# ==========Use tf is : EZR =============
# 已完成 EZR 的扰动模拟 执行时间：59.36871814727783 秒
# ==========Use tf is : F13A1 =============
# 已完成 F13A1 的扰动模拟 执行时间：59.06127381324768 秒
# ==========Use tf is : F2R =============
# 已完成 F2R 的扰动模拟 执行时间：59.68324065208435 秒
# ==========Use tf is : FABP4 =============
# 已完成 FABP4 的扰动模拟 执行时间：58.87945532798767 秒
# ==========Use tf is : FAM20C =============
# 已完成 FAM20C 的扰动模拟 执行时间：59.05762696266174 秒
# ==========Use tf is : FAM98A =============
# 已完成 FAM98A 的扰动模拟 执行时间：58.956517696380615 秒
# ==========Use tf is : FANCM =============
# 已完成 FANCM 的扰动模拟 执行时间：59.28615665435791 秒
# ==========Use tf is : FAS =============
# 已完成 FAS 的扰动模拟 执行时间：59.369091510772705 秒
# ==========Use tf is : FBP1 =============
# 已完成 FBP1 的扰动模拟 执行时间：59.384039878845215 秒
# ==========Use tf is : FBXW7 =============
# 已完成 FBXW7 的扰动模拟 执行时间：58.98686933517456 秒
# ==========Use tf is : FCER1A =============
# 已完成 FCER1A 的扰动模拟 执行时间：59.48802447319031 秒
# ==========Use tf is : FCGR3A =============
# 已完成 FCGR3A 的扰动模拟 执行时间：59.39403748512268 秒
# ==========Use tf is : FCN1 =============
# 已完成 FCN1 的扰动模拟 执行时间：59.4715576171875 秒
# ==========Use tf is : FGFR3 =============
# 已完成 FGFR3 的扰动模拟 执行时间：59.27812910079956 秒
# ==========Use tf is : FIGNL1 =============
# 已完成 FIGNL1 的扰动模拟 执行时间：59.07460880279541 秒
# ==========Use tf is : FKBP11 =============
# 已完成 FKBP11 的扰动模拟 执行时间：59.185768365859985 秒
# ==========Use tf is : FNBP1L =============
# 已完成 FNBP1L 的扰动模拟 执行时间：58.875312089920044 秒
# ==========Use tf is : FOS =============
# 已完成 FOS 的扰动模拟 执行时间：59.38451600074768 秒
# ==========Use tf is : FOXC1 =============
# 已完成 FOXC1 的扰动模拟 执行时间：59.88770270347595 秒
# ==========Use tf is : FOXD1 =============
# 已完成 FOXD1 的扰动模拟 执行时间：58.898624658584595 秒
# ==========Use tf is : FOXL1 =============
# 已完成 FOXL1 的扰动模拟 执行时间：59.19091176986694 秒
# ==========Use tf is : FOXO1 =============
# 已完成 FOXO1 的扰动模拟 执行时间：58.79118990898132 秒
# ==========Use tf is : FPR1 =============
# 已完成 FPR1 的扰动模拟 执行时间：59.56255483627319 秒
# ==========Use tf is : FPR2 =============
# 已完成 FPR2 的扰动模拟 执行时间：58.97687649726868 秒
# ==========Use tf is : FTH1 =============
# 已完成 FTH1 的扰动模拟 执行时间：59.415584564208984 秒
# ==========Use tf is : FTL =============
# 已完成 FTL 的扰动模拟 执行时间：59.02634930610657 秒
# ==========Use tf is : FYN =============
# 已完成 FYN 的扰动模拟 执行时间：59.21886706352234 秒
# ==========Use tf is : GAD1 =============
# 已完成 GAD1 的扰动模拟 执行时间：58.81516432762146 秒
# ==========Use tf is : GADD45B =============
# 已完成 GADD45B 的扰动模拟 执行时间：59.428452491760254 秒
# ==========Use tf is : GANC =============
# 已完成 GANC 的扰动模拟 执行时间：58.935357093811035 秒
# ==========Use tf is : GATA2 =============
# 已完成 GATA2 的扰动模拟 执行时间：59.00440001487732 秒
# ==========Use tf is : GATA3 =============
# 已完成 GATA3 的扰动模拟 执行时间：59.33277916908264 秒
# ==========Use tf is : GBP2 =============
# 已完成 GBP2 的扰动模拟 执行时间：59.15160298347473 秒
# ==========Use tf is : GCLM =============
# 已完成 GCLM 的扰动模拟 执行时间：59.43191695213318 秒
# ==========Use tf is : GIMAP8 =============
# 已完成 GIMAP8 的扰动模拟 执行时间：59.11817026138306 秒
# ==========Use tf is : GJA1 =============
# 已完成 GJA1 的扰动模拟 执行时间：59.02737760543823 秒
# ==========Use tf is : GLI3 =============
# 已完成 GLI3 的扰动模拟 执行时间：58.80514049530029 秒
# ==========Use tf is : GLIS3 =============
# 已完成 GLIS3 的扰动模拟 执行时间：58.665173053741455 秒
# ==========Use tf is : GNG2 =============
# 已完成 GNG2 的扰动模拟 执行时间：58.906153202056885 秒
# ==========Use tf is : GNGT2 =============
# 已完成 GNGT2 的扰动模拟 执行时间：58.89875054359436 秒
# ==========Use tf is : GNRH1 =============
# 已完成 GNRH1 的扰动模拟 执行时间：59.374656200408936 秒
# ==========Use tf is : GPX1 =============
# 已完成 GPX1 的扰动模拟 执行时间：59.11547899246216 秒
# ==========Use tf is : GRAP2 =============
# 已完成 GRAP2 的扰动模拟 执行时间：59.149658203125 秒
# ==========Use tf is : GRK5 =============
# 已完成 GRK5 的扰动模拟 执行时间：59.190258264541626 秒
# ==========Use tf is : GTF2E1 =============
# 已完成 GTF2E1 的扰动模拟 执行时间：59.337003231048584 秒
# ==========Use tf is : GTF3C1 =============
# 已完成 GTF3C1 的扰动模拟 执行时间：59.078304052352905 秒
# ==========Use tf is : GYPA =============
# 已完成 GYPA 的扰动模拟 执行时间：59.7218074798584 秒
# ==========Use tf is : GYPB =============
# 已完成 GYPB 的扰动模拟 执行时间：59.20382475852966 秒
# ==========Use tf is : GZMB =============
# 已完成 GZMB 的扰动模拟 执行时间：59.28222727775574 秒
# ==========Use tf is : H1F0 =============
# 已完成 H1F0 的扰动模拟 执行时间：59.28330206871033 秒
# ==========Use tf is : H3F3B =============
# 已完成 H3F3B 的扰动模拟 执行时间：59.00657296180725 秒
# ==========Use tf is : H6PD =============
# 已完成 H6PD 的扰动模拟 执行时间：59.70102667808533 秒
# ==========Use tf is : HAUS3 =============
# 已完成 HAUS3 的扰动模拟 执行时间：59.099642753601074 秒
# ==========Use tf is : HBA1 =============
# 已完成 HBA1 的扰动模拟 执行时间：59.30824518203735 秒
# ==========Use tf is : HBA2 =============
# 已完成 HBA2 的扰动模拟 执行时间：59.02322196960449 秒
# ==========Use tf is : HBB =============
# 已完成 HBB 的扰动模拟 执行时间：59.94082546234131 秒
# ==========Use tf is : HBD =============
# 已完成 HBD 的扰动模拟 执行时间：59.32601261138916 秒
# ==========Use tf is : HBE1 =============
# 已完成 HBE1 的扰动模拟 执行时间：59.53281927108765 秒
# ==========Use tf is : HBEGF =============
# 已完成 HBEGF 的扰动模拟 执行时间：59.38896036148071 秒
# ==========Use tf is : HBG1 =============
# 已完成 HBG1 的扰动模拟 执行时间：59.04731845855713 秒
# ==========Use tf is : HBG2 =============
# 已完成 HBG2 的扰动模拟 执行时间：59.53934025764465 秒
# ==========Use tf is : HDAC9 =============
# 已完成 HDAC9 的扰动模拟 执行时间：59.420007944107056 秒
# ==========Use tf is : HERC5 =============
# 已完成 HERC5 的扰动模拟 执行时间：59.22206401824951 秒
# ==========Use tf is : HERPUD1 =============
# 已完成 HERPUD1 的扰动模拟 执行时间：59.12440896034241 秒
# ==========Use tf is : HES1 =============
# 已完成 HES1 的扰动模拟 执行时间：59.023478746414185 秒
# ==========Use tf is : HIC2 =============
# 已完成 HIC2 的扰动模拟 执行时间：58.6968891620636 秒
# ==========Use tf is : HIF1A =============
# 已完成 HIF1A 的扰动模拟 执行时间：59.70621871948242 秒
# ==========Use tf is : HIPK2 =============
# 已完成 HIPK2 的扰动模拟 执行时间：59.434494972229004 秒
# ==========Use tf is : HIST1H1B =============
# 已完成 HIST1H1B 的扰动模拟 执行时间：59.442068099975586 秒
# ==========Use tf is : HIST1H1D =============
# 已完成 HIST1H1D 的扰动模拟 执行时间：59.452465295791626 秒
# ==========Use tf is : HIST1H2AG =============
# 已完成 HIST1H2AG 的扰动模拟 执行时间：58.77454900741577 秒
# ==========Use tf is : HIST1H2AJ =============
# 已完成 HIST1H2AJ 的扰动模拟 执行时间：59.07466197013855 秒
# ==========Use tf is : HIST1H2AM =============
# 已完成 HIST1H2AM 的扰动模拟 执行时间：59.117488622665405 秒
# ==========Use tf is : HIST1H2BG =============
# 已完成 HIST1H2BG 的扰动模拟 执行时间：59.62510800361633 秒
# ==========Use tf is : HIST1H4C =============
# 已完成 HIST1H4C 的扰动模拟 执行时间：59.390044927597046 秒
# ==========Use tf is : HIVEP1 =============
# 已完成 HIVEP1 的扰动模拟 执行时间：59.11301231384277 秒
# ==========Use tf is : HLA-DMB =============
# 已完成 HLA-DMB 的扰动模拟 执行时间：59.087671995162964 秒
# ==========Use tf is : HLA-DPA1 =============
# 已完成 HLA-DPA1 的扰动模拟 执行时间：59.55822157859802 秒
# ==========Use tf is : HLA-DPB1 =============
# 已完成 HLA-DPB1 的扰动模拟 执行时间：59.151106119155884 秒
# ==========Use tf is : HLA-DQA1 =============
# 已完成 HLA-DQA1 的扰动模拟 执行时间：59.51135730743408 秒
# ==========Use tf is : HLA-DQB1 =============
# 已完成 HLA-DQB1 的扰动模拟 执行时间：59.15070724487305 秒
# ==========Use tf is : HLA-DRA =============
# 已完成 HLA-DRA 的扰动模拟 执行时间：58.75758409500122 秒
# ==========Use tf is : HLA-DRB1 =============
# 已完成 HLA-DRB1 的扰动模拟 执行时间：59.21370768547058 秒
# ==========Use tf is : HLA-DRB5 =============
# 已完成 HLA-DRB5 的扰动模拟 执行时间：58.905808448791504 秒
# ==========Use tf is : HLF =============
# 已完成 HLF 的扰动模拟 执行时间：59.21750283241272 秒
# ==========Use tf is : HMGB1 =============
# 已完成 HMGB1 的扰动模拟 执行时间：58.716896057128906 秒
# ==========Use tf is : HMGB2 =============
# 已完成 HMGB2 的扰动模拟 执行时间：59.4051992893219 秒
# ==========Use tf is : HMMR =============
# 已完成 HMMR 的扰动模拟 执行时间：59.23592734336853 秒
# ==========Use tf is : HOPX =============
# 已完成 HOPX 的扰动模拟 执行时间：58.753687381744385 秒
# ==========Use tf is : HOXA13 =============
# 已完成 HOXA13 的扰动模拟 执行时间：58.9789354801178 秒
# ==========Use tf is : HOXA9 =============
# 已完成 HOXA9 的扰动模拟 执行时间：59.36583185195923 秒
# ==========Use tf is : HRAS =============
# 已完成 HRAS 的扰动模拟 执行时间：59.46724081039429 秒
# ==========Use tf is : HSF2 =============
# 已完成 HSF2 的扰动模拟 执行时间：59.051660776138306 秒
# ==========Use tf is : HSP90B1 =============
# 已完成 HSP90B1 的扰动模拟 执行时间：59.86749887466431 秒
# ==========Use tf is : HSPA1B =============
# 已完成 HSPA1B 的扰动模拟 执行时间：59.771849155426025 秒
# ==========Use tf is : HSPA1L =============
# 已完成 HSPA1L 的扰动模拟 执行时间：59.23084855079651 秒
# ==========Use tf is : HSPA5 =============
# 已完成 HSPA5 的扰动模拟 执行时间：59.00591421127319 秒
# ==========Use tf is : HSPA7 =============
# 已完成 HSPA7 的扰动模拟 执行时间：59.27656674385071 秒
# ==========Use tf is : HTR2B =============
# 已完成 HTR2B 的扰动模拟 执行时间：59.43984866142273 秒
# ==========Use tf is : ICAM1 =============
# 已完成 ICAM1 的扰动模拟 执行时间：59.19640588760376 秒
# ==========Use tf is : ICOS =============
# 已完成 ICOS 的扰动模拟 执行时间：59.30388879776001 秒
# ==========Use tf is : ID1 =============
# 已完成 ID1 的扰动模拟 执行时间：58.76386308670044 秒
# ==========Use tf is : ID2 =============
# 已完成 ID2 的扰动模拟 执行时间：59.249420166015625 秒
# ==========Use tf is : ID3 =============
# 已完成 ID3 的扰动模拟 执行时间：58.81397533416748 秒
# ==========Use tf is : IER3 =============
# 已完成 IER3 的扰动模拟 执行时间：59.04967522621155 秒
# ==========Use tf is : IFI27 =============
# 已完成 IFI27 的扰动模拟 执行时间：58.84711766242981 秒
# ==========Use tf is : IFI30 =============
# 已完成 IFI30 的扰动模拟 执行时间：59.00534677505493 秒
# ==========Use tf is : IFI6 =============
# 已完成 IFI6 的扰动模拟 执行时间：58.70348334312439 秒
# ==========Use tf is : IFIH1 =============
# 已完成 IFIH1 的扰动模拟 执行时间：59.15540933609009 秒
# ==========Use tf is : IFIT1 =============
# 已完成 IFIT1 的扰动模拟 执行时间：59.41744875907898 秒
# ==========Use tf is : IFIT1B =============
# 已完成 IFIT1B 的扰动模拟 执行时间：59.075820446014404 秒
# ==========Use tf is : IFIT3 =============
# 已完成 IFIT3 的扰动模拟 执行时间：59.564003705978394 秒
# ==========Use tf is : IFITM1 =============
# 已完成 IFITM1 的扰动模拟 执行时间：58.944689989089966 秒
# ==========Use tf is : IFNG =============
# 已完成 IFNG 的扰动模拟 执行时间：59.197880029678345 秒
# ==========Use tf is : IGF1 =============
# 已完成 IGF1 的扰动模拟 执行时间：58.91256308555603 秒
# ==========Use tf is : IGF1R =============
# 已完成 IGF1R 的扰动模拟 执行时间：59.22356724739075 秒
# ==========Use tf is : IGF2 =============
# 已完成 IGF2 的扰动模拟 执行时间：59.79437494277954 秒
# ==========Use tf is : IGFBP5 =============
# 已完成 IGFBP5 的扰动模拟 执行时间：59.30338954925537 秒
# ==========Use tf is : IGLL5 =============
# 已完成 IGLL5 的扰动模拟 执行时间：59.26368284225464 秒
# ==========Use tf is : IKZF2 =============
# 已完成 IKZF2 的扰动模拟 执行时间：58.80907320976257 秒
# ==========Use tf is : IKZF3 =============
# 已完成 IKZF3 的扰动模拟 执行时间：59.14859962463379 秒
# ==========Use tf is : IL10RA =============
# 已完成 IL10RA 的扰动模拟 执行时间：58.91853857040405 秒
# ==========Use tf is : IL12RB2 =============
# 已完成 IL12RB2 的扰动模拟 执行时间：59.330713510513306 秒
# ==========Use tf is : IL13RA1 =============
# 已完成 IL13RA1 的扰动模拟 执行时间：59.192569732666016 秒
# ==========Use tf is : IL15 =============
# 已完成 IL15 的扰动模拟 执行时间：59.3587441444397 秒
# ==========Use tf is : IL18R1 =============
# 已完成 IL18R1 的扰动模拟 执行时间：59.00628399848938 秒
# ==========Use tf is : IL1B =============
# 已完成 IL1B 的扰动模拟 执行时间：59.828020095825195 秒
# ==========Use tf is : IL2RA =============
# 已完成 IL2RA 的扰动模拟 执行时间：58.98420524597168 秒
# ==========Use tf is : IL2RB =============
# 已完成 IL2RB 的扰动模拟 执行时间：59.312068939208984 秒
# ==========Use tf is : IL32 =============
# 已完成 IL32 的扰动模拟 执行时间：59.57162165641785 秒
# ==========Use tf is : IL4R =============
# 已完成 IL4R 的扰动模拟 执行时间：58.954219579696655 秒
# ==========Use tf is : IL5RA =============
# 已完成 IL5RA 的扰动模拟 执行时间：59.27723526954651 秒
# ==========Use tf is : IL6ST =============
# 已完成 IL6ST 的扰动模拟 执行时间：59.49345278739929 秒
# ==========Use tf is : IL7R =============
# 已完成 IL7R 的扰动模拟 执行时间：59.35055708885193 秒
# ==========Use tf is : ING1 =============
# 已完成 ING1 的扰动模拟 执行时间：59.5512797832489 秒
# ==========Use tf is : INPP4A =============
# 已完成 INPP4A 的扰动模拟 执行时间：59.240928411483765 秒
# ==========Use tf is : INTS2 =============
# 已完成 INTS2 的扰动模拟 执行时间：59.44979691505432 秒
# ==========Use tf is : IRF1 =============
# 已完成 IRF1 的扰动模拟 执行时间：59.11018919944763 秒
# ==========Use tf is : IRF4 =============
# 已完成 IRF4 的扰动模拟 执行时间：59.17853331565857 秒
# ==========Use tf is : IRF8 =============
# 已完成 IRF8 的扰动模拟 执行时间：59.28979706764221 秒
# ==========Use tf is : IRS2 =============
# 已完成 IRS2 的扰动模拟 执行时间：59.45310854911804 秒
# ==========Use tf is : ISG15 =============
# 已完成 ISG15 的扰动模拟 执行时间：58.8675594329834 秒
# ==========Use tf is : ISG20 =============
# 已完成 ISG20 的扰动模拟 执行时间：59.34684610366821 秒
# ==========Use tf is : ISG20L2 =============
# 已完成 ISG20L2 的扰动模拟 执行时间：59.424254417419434 秒
# ==========Use tf is : ITGA6 =============
# 已完成 ITGA6 的扰动模拟 执行时间：59.192145586013794 秒
# ==========Use tf is : ITGAX =============
# 已完成 ITGAX 的扰动模拟 执行时间：59.12940740585327 秒
# ==========Use tf is : ITK =============
# 已完成 ITK 的扰动模拟 执行时间：59.400155544281006 秒
# ==========Use tf is : JAZF1 =============
# 已完成 JAZF1 的扰动模拟 执行时间：59.30545926094055 秒
# ==========Use tf is : JCHAIN =============
# 已完成 JCHAIN 的扰动模拟 执行时间：58.88098978996277 秒
# ==========Use tf is : JMY =============
# 已完成 JMY 的扰动模拟 执行时间：59.58282399177551 秒
# ==========Use tf is : JUN =============
# 已完成 JUN 的扰动模拟 执行时间：59.38144564628601 秒
# ==========Use tf is : KAT2B =============
# 已完成 KAT2B 的扰动模拟 执行时间：59.5914888381958 秒
# ==========Use tf is : KCTD12 =============
# 已完成 KCTD12 的扰动模拟 执行时间：59.44867968559265 秒
# ==========Use tf is : KIAA1551 =============
# 已完成 KIAA1551 的扰动模拟 执行时间：59.35337042808533 秒
# ==========Use tf is : KIF14 =============
# 已完成 KIF14 的扰动模拟 执行时间：59.08929681777954 秒
# ==========Use tf is : KIFAP3 =============
# 已完成 KIFAP3 的扰动模拟 执行时间：59.02621912956238 秒
# ==========Use tf is : KIR2DL4 =============
# 已完成 KIR2DL4 的扰动模拟 执行时间：59.33574199676514 秒
# ==========Use tf is : KLC1 =============
# 已完成 KLC1 的扰动模拟 执行时间：59.02746224403381 秒
# ==========Use tf is : KLF11 =============
# 已完成 KLF11 的扰动模拟 执行时间：59.45625829696655 秒
# ==========Use tf is : KLF12 =============
# 已完成 KLF12 的扰动模拟 执行时间：59.00353121757507 秒
# ==========Use tf is : KLF2 =============
# 已完成 KLF2 的扰动模拟 执行时间：59.36757564544678 秒
# ==========Use tf is : KLF6 =============
# 已完成 KLF6 的扰动模拟 执行时间：59.09848427772522 秒
# ==========Use tf is : KLRB1 =============
# 已完成 KLRB1 的扰动模拟 执行时间：59.008100748062134 秒
# ==========Use tf is : KLRC1 =============
# 已完成 KLRC1 的扰动模拟 执行时间：58.854074001312256 秒
# ==========Use tf is : KLRC2 =============
# 已完成 KLRC2 的扰动模拟 执行时间：59.24104404449463 秒
# ==========Use tf is : KLRD1 =============
# 已完成 KLRD1 的扰动模拟 执行时间：59.314632177352905 秒
# ==========Use tf is : KLRK1 =============
# 已完成 KLRK1 的扰动模拟 执行时间：59.2931923866272 秒
# ==========Use tf is : KNL1 =============
# 已完成 KNL1 的扰动模拟 执行时间：59.563297748565674 秒
# ==========Use tf is : KPNA5 =============
# 已完成 KPNA5 的扰动模拟 执行时间：59.75956678390503 秒
# ==========Use tf is : L3MBTL3 =============
# 已完成 L3MBTL3 的扰动模拟 执行时间：59.40549921989441 秒
# ==========Use tf is : LAMA4 =============
# 已完成 LAMA4 的扰动模拟 执行时间：59.36645269393921 秒
# ==========Use tf is : LAT =============
# 已完成 LAT 的扰动模拟 执行时间：59.31781315803528 秒
# ==========Use tf is : LBX2 =============
# 已完成 LBX2 的扰动模拟 执行时间：59.180243730545044 秒
# ==========Use tf is : LCK =============
# 已完成 LCK 的扰动模拟 执行时间：59.6710479259491 秒
# ==========Use tf is : LDB1 =============
# 已完成 LDB1 的扰动模拟 执行时间：59.28384327888489 秒
# ==========Use tf is : LDLR =============
# 已完成 LDLR 的扰动模拟 执行时间：59.12278962135315 秒
# ==========Use tf is : LEF1 =============
# 已完成 LEF1 的扰动模拟 执行时间：59.39800238609314 秒
# ==========Use tf is : LEPR =============
# 已完成 LEPR 的扰动模拟 执行时间：59.35484790802002 秒
# ==========Use tf is : LGALS1 =============
# 已完成 LGALS1 的扰动模拟 执行时间：59.32546305656433 秒
# ==========Use tf is : LGALS2 =============
# 已完成 LGALS2 的扰动模拟 执行时间：59.44151210784912 秒
# ==========Use tf is : LGALS3 =============
# 已完成 LGALS3 的扰动模拟 执行时间：59.17399072647095 秒
# ==========Use tf is : LILRB1 =============
# 已完成 LILRB1 的扰动模拟 执行时间：59.128878355026245 秒
# ==========Use tf is : LILRB2 =============
# 已完成 LILRB2 的扰动模拟 执行时间：59.29786038398743 秒
# ==========Use tf is : LILRB3 =============
# 已完成 LILRB3 的扰动模拟 执行时间：58.954221963882446 秒
# ==========Use tf is : LMNA =============
# 已完成 LMNA 的扰动模拟 执行时间：60.0339879989624 秒
# ==========Use tf is : LMO4 =============
# 已完成 LMO4 的扰动模拟 执行时间：59.519105672836304 秒
# ==========Use tf is : LPAR6 =============
# 已完成 LPAR6 的扰动模拟 执行时间：58.92124557495117 秒
# ==========Use tf is : LPL =============
# 已完成 LPL 的扰动模拟 执行时间：59.410919427871704 秒
# ==========Use tf is : LRP1 =============
# 已完成 LRP1 的扰动模拟 执行时间：59.13139367103577 秒
# ==========Use tf is : LRRK2 =============
# 已完成 LRRK2 的扰动模拟 执行时间：59.23160362243652 秒
# ==========Use tf is : LTB =============
# 已完成 LTB 的扰动模拟 执行时间：59.41119384765625 秒
# ==========Use tf is : LTF =============
# 已完成 LTF 的扰动模拟 执行时间：59.071709632873535 秒
# ==========Use tf is : LY96 =============
# 已完成 LY96 的扰动模拟 执行时间：58.9222948551178 秒
# ==========Use tf is : LYST =============
# 已完成 LYST 的扰动模拟 执行时间：59.17853498458862 秒
# ==========Use tf is : LYZ =============
# 已完成 LYZ 的扰动模拟 执行时间：59.06652212142944 秒
# ==========Use tf is : LZTFL1 =============
# 已完成 LZTFL1 的扰动模拟 执行时间：58.87505078315735 秒
# ==========Use tf is : MAF =============
# 已完成 MAF 的扰动模拟 执行时间：59.36838984489441 秒
# ==========Use tf is : MAFB =============
# 已完成 MAFB 的扰动模拟 执行时间：59.24413204193115 秒
# ==========Use tf is : MAFF =============
# 已完成 MAFF 的扰动模拟 执行时间：59.22856783866882 秒
# ==========Use tf is : MAL =============
# 已完成 MAL 的扰动模拟 执行时间：59.28488039970398 秒
# ==========Use tf is : MALT1 =============
# 已完成 MALT1 的扰动模拟 执行时间：59.05517554283142 秒
# ==========Use tf is : MAML2 =============
# 已完成 MAML2 的扰动模拟 执行时间：59.05706596374512 秒
# ==========Use tf is : MAP1A =============
# 已完成 MAP1A 的扰动模拟 执行时间：59.283170223236084 秒
# ==========Use tf is : MAP2 =============
# 已完成 MAP2 的扰动模拟 执行时间：59.08849740028381 秒
# ==========Use tf is : MAP2K6 =============
# 已完成 MAP2K6 的扰动模拟 执行时间：59.46170783042908 秒
# ==========Use tf is : MAP3K21 =============
# 已完成 MAP3K21 的扰动模拟 执行时间：58.909438133239746 秒
# ==========Use tf is : MAP3K8 =============
# 已完成 MAP3K8 的扰动模拟 执行时间：59.357661962509155 秒
# ==========Use tf is : MAP4K4 =============
# 已完成 MAP4K4 的扰动模拟 执行时间：58.97094202041626 秒
# ==========Use tf is : MAPK13 =============
# 已完成 MAPK13 的扰动模拟 执行时间：58.844627141952515 秒
# ==========Use tf is : MARCO =============
# 已完成 MARCO 的扰动模拟 执行时间：59.29536819458008 秒
# ==========Use tf is : MAST4 =============
# 已完成 MAST4 的扰动模拟 执行时间：59.45801901817322 秒
# ==========Use tf is : MDM2 =============
# 已完成 MDM2 的扰动模拟 执行时间：59.37018418312073 秒
# ==========Use tf is : MECOM =============
# 已完成 MECOM 的扰动模拟 执行时间：59.15730023384094 秒
# ==========Use tf is : MGAM =============
# 已完成 MGAM 的扰动模拟 执行时间：59.407825231552124 秒
# ==========Use tf is : MKI67 =============
# 已完成 MKI67 的扰动模拟 执行时间：59.5792133808136 秒
# ==========Use tf is : MLH3 =============
# 已完成 MLH3 的扰动模拟 执行时间：58.722508907318115 秒
# ==========Use tf is : MME =============
# 已完成 MME 的扰动模拟 执行时间：59.49817228317261 秒
# ==========Use tf is : MMP7 =============
# 已完成 MMP7 的扰动模拟 执行时间：59.41399669647217 秒
# ==========Use tf is : MNDA =============
# 已完成 MNDA 的扰动模拟 执行时间：59.053160190582275 秒
# ==========Use tf is : MOCS2 =============
# 已完成 MOCS2 的扰动模拟 执行时间：59.137600898742676 秒
# ==========Use tf is : MPO =============
# 已完成 MPO 的扰动模拟 执行时间：59.66467475891113 秒
# ==========Use tf is : MS4A1 =============
# 已完成 MS4A1 的扰动模拟 执行时间：59.58543348312378 秒
# ==========Use tf is : MS4A2 =============
# 已完成 MS4A2 的扰动模拟 执行时间：59.48436188697815 秒
# ==========Use tf is : MS4A3 =============
# 已完成 MS4A3 的扰动模拟 执行时间：58.890398025512695 秒
# ==========Use tf is : MS4A7 =============
# 已完成 MS4A7 的扰动模拟 执行时间：59.264119386672974 秒
# ==========Use tf is : MT1M =============
# 已完成 MT1M 的扰动模拟 执行时间：59.364919662475586 秒
# ==========Use tf is : MT2A =============
# 已完成 MT2A 的扰动模拟 执行时间：59.27361702919006 秒
# ==========Use tf is : MTF1 =============
# 已完成 MTF1 的扰动模拟 执行时间：59.19479036331177 秒
# ==========Use tf is : MTUS1 =============
# 已完成 MTUS1 的扰动模拟 执行时间：58.83777475357056 秒
# ==========Use tf is : MX1 =============
# 已完成 MX1 的扰动模拟 执行时间：58.861623764038086 秒
# ==========Use tf is : MX2 =============
# 已完成 MX2 的扰动模拟 执行时间：59.13831686973572 秒
# ==========Use tf is : MYBL1 =============
# 已完成 MYBL1 的扰动模拟 执行时间：59.867302894592285 秒
# ==========Use tf is : MYC =============
# 已完成 MYC 的扰动模拟 执行时间：58.99859118461609 秒
# ==========Use tf is : MYLK =============
# 已完成 MYLK 的扰动模拟 执行时间：59.49116349220276 秒
# ==========Use tf is : MYO5A =============
# 已完成 MYO5A 的扰动模拟 执行时间：59.73096418380737 秒
# ==========Use tf is : NAMPT =============
# 已完成 NAMPT 的扰动模拟 执行时间：59.26861524581909 秒
# ==========Use tf is : NAV3 =============
# 已完成 NAV3 的扰动模拟 执行时间：59.764973163604736 秒
# ==========Use tf is : NCF1 =============
# 已完成 NCF1 的扰动模拟 执行时间：59.06447649002075 秒
# ==========Use tf is : NCF2 =============
# 已完成 NCF2 的扰动模拟 执行时间：59.89116358757019 秒
# ==========Use tf is : NCK2 =============
# 已完成 NCK2 的扰动模拟 执行时间：59.19135808944702 秒
# ==========Use tf is : NEAT1 =============
# 已完成 NEAT1 的扰动模拟 执行时间：59.627233266830444 秒
# ==========Use tf is : NEDD9 =============
# 已完成 NEDD9 的扰动模拟 执行时间：59.016923666000366 秒
# ==========Use tf is : NEUROD1 =============
# 已完成 NEUROD1 的扰动模拟 执行时间：59.67291188240051 秒
# ==========Use tf is : NEUROD2 =============
# 已完成 NEUROD2 的扰动模拟 执行时间：59.0927472114563 秒
# ==========Use tf is : NFATC2 =============
# 已完成 NFATC2 的扰动模拟 执行时间：59.54169297218323 秒
# ==========Use tf is : NFKB2 =============
# 已完成 NFKB2 的扰动模拟 执行时间：59.57197093963623 秒
# ==========Use tf is : NFKBIA =============
# 已完成 NFKBIA 的扰动模拟 执行时间：59.252902030944824 秒
# ==========Use tf is : NOS3 =============
# 已完成 NOS3 的扰动模拟 执行时间：59.111342430114746 秒
# ==========Use tf is : NOTCH1 =============
# 已完成 NOTCH1 的扰动模拟 执行时间：59.00023674964905 秒
# ==========Use tf is : NPAT =============
# 已完成 NPAT 的扰动模拟 执行时间：59.2507483959198 秒
# ==========Use tf is : NPTX2 =============
# 已完成 NPTX2 的扰动模拟 执行时间：59.5918083190918 秒
# ==========Use tf is : NQO1 =============
# 已完成 NQO1 的扰动模拟 执行时间：59.544758796691895 秒
# ==========Use tf is : NR2F2 =============
# 已完成 NR2F2 的扰动模拟 执行时间：59.26106238365173 秒
# ==========Use tf is : NR3C2 =============
# 已完成 NR3C2 的扰动模拟 执行时间：59.24109411239624 秒
# ==========Use tf is : NR4A1 =============
# 已完成 NR4A1 的扰动模拟 执行时间：59.453874349594116 秒
# ==========Use tf is : NR4A2 =============
# 已完成 NR4A2 的扰动模拟 执行时间：59.50715208053589 秒
# ==========Use tf is : NRG1 =============
# 已完成 NRG1 的扰动模拟 执行时间：59.36641883850098 秒
# ==========Use tf is : NRIP1 =============
# 已完成 NRIP1 的扰动模拟 执行时间：59.060330867767334 秒
# ==========Use tf is : NSG1 =============
# 已完成 NSG1 的扰动模拟 执行时间：59.1053900718689 秒
# ==========Use tf is : NTRK2 =============
# 已完成 NTRK2 的扰动模拟 执行时间：59.37388753890991 秒
# ==========Use tf is : NTS =============
# 已完成 NTS 的扰动模拟 执行时间：59.350038290023804 秒
# ==========Use tf is : NUSAP1 =============
# 已完成 NUSAP1 的扰动模拟 执行时间：59.70282793045044 秒
# ==========Use tf is : OAS1 =============
# 已完成 OAS1 的扰动模拟 执行时间：59.11017870903015 秒
# ==========Use tf is : OAS2 =============
# 已完成 OAS2 的扰动模拟 执行时间：59.09399604797363 秒
# ==========Use tf is : OPTN =============
# 已完成 OPTN 的扰动模拟 执行时间：58.95717811584473 秒
# ==========Use tf is : OSM =============
# 已完成 OSM 的扰动模拟 执行时间：59.190467834472656 秒
# ==========Use tf is : OSMR =============
# 已完成 OSMR 的扰动模拟 执行时间：58.753215312957764 秒
# ==========Use tf is : P2RY13 =============
# 已完成 P2RY13 的扰动模拟 执行时间：59.13219451904297 秒
# ==========Use tf is : P2RY14 =============
# 已完成 P2RY14 的扰动模拟 执行时间：59.476455211639404 秒
# ==========Use tf is : PADI4 =============
# 已完成 PADI4 的扰动模拟 执行时间：59.57716631889343 秒
# ==========Use tf is : PAG1 =============
# 已完成 PAG1 的扰动模拟 执行时间：59.006086349487305 秒
# ==========Use tf is : PALLD =============
# 已完成 PALLD 的扰动模拟 执行时间：59.14679312705994 秒
# ==========Use tf is : PAPPA =============
# 已完成 PAPPA 的扰动模拟 执行时间：58.848604917526245 秒
# ==========Use tf is : PAX5 =============
# 已完成 PAX5 的扰动模拟 执行时间：59.67871165275574 秒
# ==========Use tf is : PAX6 =============
# 已完成 PAX6 的扰动模拟 执行时间：58.82102608680725 秒
# ==========Use tf is : PBX1 =============
# 已完成 PBX1 的扰动模拟 执行时间：59.09371256828308 秒
# ==========Use tf is : PCDH8 =============
# 已完成 PCDH8 的扰动模拟 执行时间：59.52845335006714 秒
# ==========Use tf is : PCED1B =============
# 已完成 PCED1B 的扰动模拟 执行时间：58.7932665348053 秒
# ==========Use tf is : PCGF5 =============
# 已完成 PCGF5 的扰动模拟 执行时间：59.827701807022095 秒
# ==========Use tf is : PDE4B =============
# 已完成 PDE4B 的扰动模拟 执行时间：59.058117628097534 秒
# ==========Use tf is : PDE4D =============
# 已完成 PDE4D 的扰动模拟 执行时间：59.58187937736511 秒
# ==========Use tf is : PDE8A =============
# 已完成 PDE8A 的扰动模拟 执行时间：59.139546155929565 秒
# ==========Use tf is : PDGFA =============
# 已完成 PDGFA 的扰动模拟 执行时间：59.375866413116455 秒
# ==========Use tf is : PDK1 =============
# 已完成 PDK1 的扰动模拟 执行时间：59.12200140953064 秒
# ==========Use tf is : PDK4 =============
# 已完成 PDK4 的扰动模拟 执行时间：59.05342721939087 秒
# ==========Use tf is : PDPK1 =============
# 已完成 PDPK1 的扰动模拟 执行时间：59.22077298164368 秒
# ==========Use tf is : PELI1 =============
# 已完成 PELI1 的扰动模拟 执行时间：59.006489753723145 秒
# ==========Use tf is : PEX1 =============
# 已完成 PEX1 的扰动模拟 执行时间：59.54473280906677 秒
# ==========Use tf is : PFKFB3 =============
# 已完成 PFKFB3 的扰动模拟 执行时间：58.61491060256958 秒
# ==========Use tf is : PGAP1 =============
# 已完成 PGAP1 的扰动模拟 执行时间：59.66167140007019 秒
# ==========Use tf is : PHLDB2 =============
# 已完成 PHLDB2 的扰动模拟 执行时间：59.12903571128845 秒
# ==========Use tf is : PIK3C2B =============
# 已完成 PIK3C2B 的扰动模拟 执行时间：59.05987906455994 秒
# ==========Use tf is : PIK3CA =============
# 已完成 PIK3CA 的扰动模拟 执行时间：59.39731764793396 秒
# ==========Use tf is : PIM2 =============
# 已完成 PIM2 的扰动模拟 执行时间：59.79802227020264 秒
# ==========Use tf is : PITX1 =============
# 已完成 PITX1 的扰动模拟 执行时间：59.7312068939209 秒
# ==========Use tf is : PLAG1 =============
# 已完成 PLAG1 的扰动模拟 执行时间：59.424357175827026 秒
# ==========Use tf is : PLAT =============
# 已完成 PLAT 的扰动模拟 执行时间：59.09230852127075 秒
# ==========Use tf is : PLAUR =============
# 已完成 PLAUR 的扰动模拟 执行时间：59.54450726509094 秒
# ==========Use tf is : PLBD1 =============
# 已完成 PLBD1 的扰动模拟 执行时间：59.616923332214355 秒
# ==========Use tf is : PLK2 =============
# 已完成 PLK2 的扰动模拟 执行时间：58.792561054229736 秒
# ==========Use tf is : PMAIP1 =============
# 已完成 PMAIP1 的扰动模拟 执行时间：59.52213788032532 秒
# ==========Use tf is : POLR3G =============
# 已完成 POLR3G 的扰动模拟 执行时间：58.93430781364441 秒
# ==========Use tf is : POU2AF1 =============
# 已完成 POU2AF1 的扰动模拟 执行时间：59.56957268714905 秒
# ==========Use tf is : POU2F2 =============
# 已完成 POU2F2 的扰动模拟 执行时间：59.3184072971344 秒
# ==========Use tf is : POU4F1 =============
# 已完成 POU4F1 的扰动模拟 执行时间：59.363149642944336 秒
# ==========Use tf is : PPARD =============
# 已完成 PPARD 的扰动模拟 执行时间：59.470258712768555 秒
# ==========Use tf is : PPARGC1A =============
# 已完成 PPARGC1A 的扰动模拟 执行时间：58.901164054870605 秒
# ==========Use tf is : PPP1R2 =============
# 已完成 PPP1R2 的扰动模拟 执行时间：59.141669034957886 秒
# ==========Use tf is : PRAME =============
# 已完成 PRAME 的扰动模拟 执行时间：58.879494428634644 秒
# ==========Use tf is : PRDM1 =============
# 已完成 PRDM1 的扰动模拟 执行时间：59.33586597442627 秒
# ==========Use tf is : PRDM5 =============
# 已完成 PRDM5 的扰动模拟 执行时间：59.092790603637695 秒
# ==========Use tf is : PRF1 =============
# 已完成 PRF1 的扰动模拟 执行时间：58.93145442008972 秒
# ==========Use tf is : PRKAB2 =============
# 已完成 PRKAB2 的扰动模拟 执行时间：59.62213969230652 秒
# ==========Use tf is : PRKAG2 =============
# 已完成 PRKAG2 的扰动模拟 执行时间：58.80649542808533 秒
# ==========Use tf is : PRKCE =============
# 已完成 PRKCE 的扰动模拟 执行时间：59.20158123970032 秒
# ==========Use tf is : PRKG2 =============
# 已完成 PRKG2 的扰动模拟 执行时间：59.12948226928711 秒
# ==========Use tf is : PRLR =============
# 已完成 PRLR 的扰动模拟 执行时间：60.087382078170776 秒
# ==========Use tf is : PRTN3 =============
# 已完成 PRTN3 的扰动模拟 执行时间：59.05666160583496 秒
# ==========Use tf is : PTCH1 =============
# 已完成 PTCH1 的扰动模拟 执行时间：60.00872492790222 秒
# ==========Use tf is : PTGDS =============
# 已完成 PTGDS 的扰动模拟 执行时间：59.17771673202515 秒
# ==========Use tf is : PTGS2 =============
# 已完成 PTGS2 的扰动模拟 执行时间：59.196829319000244 秒
# ==========Use tf is : PTPRJ =============
# 已完成 PTPRJ 的扰动模拟 执行时间：59.07298398017883 秒
# ==========Use tf is : PTS =============
# 已完成 PTS 的扰动模拟 执行时间：59.65300369262695 秒
# ==========Use tf is : PURA =============
# 已完成 PURA 的扰动模拟 执行时间：59.23013377189636 秒
# ==========Use tf is : RAB8B =============
# 已完成 RAB8B 的扰动模拟 执行时间：58.81654906272888 秒
# ==========Use tf is : RAF1 =============
# 已完成 RAF1 的扰动模拟 执行时间：59.33743858337402 秒
# ==========Use tf is : RAG1 =============
# 已完成 RAG1 的扰动模拟 执行时间：58.898486852645874 秒
# ==========Use tf is : RAG2 =============
# 已完成 RAG2 的扰动模拟 执行时间：59.1257688999176 秒
# ==========Use tf is : RALGPS2 =============
# 已完成 RALGPS2 的扰动模拟 执行时间：59.02181100845337 秒
# ==========Use tf is : RAP2A =============
# 已完成 RAP2A 的扰动模拟 执行时间：59.37936854362488 秒
# ==========Use tf is : RAPGEF6 =============
# 已完成 RAPGEF6 的扰动模拟 执行时间：59.43163323402405 秒
# ==========Use tf is : RASA2 =============
# 已完成 RASA2 的扰动模拟 执行时间：59.550639629364014 秒
# ==========Use tf is : RASSF5 =============
# 已完成 RASSF5 的扰动模拟 执行时间：59.35298681259155 秒
# ==========Use tf is : RBBP5 =============
# 已完成 RBBP5 的扰动模拟 执行时间：58.96733093261719 秒
# ==========Use tf is : RBM47 =============
# 已完成 RBM47 的扰动模拟 执行时间：58.89457607269287 秒
# ==========Use tf is : RBPJ =============
# 已完成 RBPJ 的扰动模拟 执行时间：59.182663440704346 秒
# ==========Use tf is : RECK =============
# 已完成 RECK 的扰动模拟 执行时间：59.4853720664978 秒
# ==========Use tf is : REL =============
# 已完成 REL 的扰动模拟 执行时间：59.47086524963379 秒
# ==========Use tf is : RETN =============
# 已完成 RETN 的扰动模拟 执行时间：59.10862398147583 秒
# ==========Use tf is : RGS1 =============
# 已完成 RGS1 的扰动模拟 执行时间：58.75192952156067 秒
# ==========Use tf is : RGS16 =============
# 已完成 RGS16 的扰动模拟 执行时间：59.93338203430176 秒
# ==========Use tf is : RGS2 =============
# 已完成 RGS2 的扰动模拟 执行时间：59.23814630508423 秒
# ==========Use tf is : RGS7 =============
# 已完成 RGS7 的扰动模拟 执行时间：59.412715911865234 秒
# ==========Use tf is : RHAG =============
# 已完成 RHAG 的扰动模拟 执行时间：59.42283082008362 秒
# ==========Use tf is : RHOB =============
# 已完成 RHOB 的扰动模拟 执行时间：59.02862548828125 秒
# ==========Use tf is : RHOH =============
# 已完成 RHOH 的扰动模拟 执行时间：59.37673616409302 秒
# ==========Use tf is : RICTOR =============
# 已完成 RICTOR 的扰动模拟 执行时间：59.054744720458984 秒
# ==========Use tf is : RIT1 =============
# 已完成 RIT1 的扰动模拟 执行时间：59.38960862159729 秒
# ==========Use tf is : RORA =============
# 已完成 RORA 的扰动模拟 执行时间：58.71225357055664 秒
# ==========Use tf is : RORC =============
# 已完成 RORC 的扰动模拟 执行时间：59.38972806930542 秒
# ==========Use tf is : RPS3A =============
# 已完成 RPS3A 的扰动模拟 执行时间：59.087106704711914 秒
# ==========Use tf is : RPS6 =============
# 已完成 RPS6 的扰动模拟 执行时间：59.14166283607483 秒
# ==========Use tf is : RPS6KA5 =============
# 已完成 RPS6KA5 的扰动模拟 执行时间：59.087515115737915 秒
# ==========Use tf is : RUNX1T1 =============
# 已完成 RUNX1T1 的扰动模拟 执行时间：59.39712834358215 秒
# ==========Use tf is : RUNX3 =============
# 已完成 RUNX3 的扰动模拟 执行时间：59.09515905380249 秒
# ==========Use tf is : RXRA =============
# 已完成 RXRA 的扰动模拟 执行时间：59.080013275146484 秒
# ==========Use tf is : RYK =============
# 已完成 RYK 的扰动模拟 执行时间：59.45999360084534 秒
# ==========Use tf is : S100A10 =============
# 已完成 S100A10 的扰动模拟 执行时间：59.68150210380554 秒
# ==========Use tf is : S100A12 =============
# 已完成 S100A12 的扰动模拟 执行时间：59.79527282714844 秒
# ==========Use tf is : S100A8 =============
# 已完成 S100A8 的扰动模拟 执行时间：59.04667782783508 秒
# ==========Use tf is : S100A9 =============
# 已完成 S100A9 的扰动模拟 执行时间：59.303433656692505 秒
# ==========Use tf is : S100B =============
# 已完成 S100B 的扰动模拟 执行时间：60.03500723838806 秒
# ==========Use tf is : S1PR1 =============
# 已完成 S1PR1 的扰动模拟 执行时间：58.91928696632385 秒
# ==========Use tf is : S1PR5 =============
# 已完成 S1PR5 的扰动模拟 执行时间：59.794639587402344 秒
# ==========Use tf is : SACS =============
# 已完成 SACS 的扰动模拟 执行时间：59.2791268825531 秒
# ==========Use tf is : SAMD9L =============
# 已完成 SAMD9L 的扰动模拟 执行时间：59.60526371002197 秒
# ==========Use tf is : SAMHD1 =============
# 已完成 SAMHD1 的扰动模拟 执行时间：58.851606607437134 秒
# ==========Use tf is : SAMSN1 =============
# 已完成 SAMSN1 的扰动模拟 执行时间：58.98231863975525 秒
# ==========Use tf is : SAP30 =============
# 已完成 SAP30 的扰动模拟 执行时间：59.07471752166748 秒
# ==========Use tf is : SAT1 =============
# 已完成 SAT1 的扰动模拟 执行时间：59.18996071815491 秒
# ==========Use tf is : SDC1 =============
# 已完成 SDC1 的扰动模拟 执行时间：59.13837265968323 秒
# ==========Use tf is : SEL1L =============
# 已完成 SEL1L 的扰动模拟 执行时间：59.281925201416016 秒
# ==========Use tf is : SELP =============
# 已完成 SELP 的扰动模拟 执行时间：59.14481735229492 秒
# ==========Use tf is : SERPINA1 =============
# 已完成 SERPINA1 的扰动模拟 执行时间：59.428369760513306 秒
# ==========Use tf is : SERPINB2 =============
# 已完成 SERPINB2 的扰动模拟 执行时间：59.52763080596924 秒
# ==========Use tf is : SERPINE1 =============
# 已完成 SERPINE1 的扰动模拟 执行时间：59.51425099372864 秒
# ==========Use tf is : SGK1 =============
# 已完成 SGK1 的扰动模拟 执行时间：58.901705503463745 秒
# ==========Use tf is : SGPL1 =============
# 已完成 SGPL1 的扰动模拟 执行时间：59.11464500427246 秒
# ==========Use tf is : SGPP1 =============
# 已完成 SGPP1 的扰动模拟 执行时间：59.05905270576477 秒
# ==========Use tf is : SH2D1A =============
# 已完成 SH2D1A 的扰动模拟 执行时间：59.41208028793335 秒
# ==========Use tf is : SH2D1B =============
# 已完成 SH2D1B 的扰动模拟 执行时间：59.255845069885254 秒
# ==========Use tf is : SH3BP5 =============
# 已完成 SH3BP5 的扰动模拟 执行时间：58.977250814437866 秒
# ==========Use tf is : SIGLEC6 =============
# 已完成 SIGLEC6 的扰动模拟 执行时间：59.01898908615112 秒
# ==========Use tf is : SIRT1 =============
# 已完成 SIRT1 的扰动模拟 执行时间：59.346938371658325 秒
# ==========Use tf is : SKIL =============
# 已完成 SKIL 的扰动模拟 执行时间：58.98082756996155 秒
# ==========Use tf is : SLA =============
# 已完成 SLA 的扰动模拟 执行时间：59.1855731010437 秒
# ==========Use tf is : SLAMF1 =============
# 已完成 SLAMF1 的扰动模拟 执行时间：59.354936361312866 秒
# ==========Use tf is : SLAMF6 =============
# 已完成 SLAMF6 的扰动模拟 执行时间：59.36071491241455 秒
# ==========Use tf is : SLAMF7 =============
# 已完成 SLAMF7 的扰动模拟 执行时间：58.83174729347229 秒
# ==========Use tf is : SLC11A1 =============
# 已完成 SLC11A1 的扰动模拟 执行时间：59.01735877990723 秒
# ==========Use tf is : SLC1A3 =============
# 已完成 SLC1A3 的扰动模拟 执行时间：58.6661639213562 秒
# ==========Use tf is : SLC22A23 =============
# 已完成 SLC22A23 的扰动模拟 执行时间：59.3810350894928 秒
# ==========Use tf is : SLC22A3 =============
# 已完成 SLC22A3 的扰动模拟 执行时间：58.899895668029785 秒
# ==========Use tf is : SLC24A4 =============
# 已完成 SLC24A4 的扰动模拟 执行时间：59.18752861022949 秒
# ==========Use tf is : SLC2A4 =============
# 已完成 SLC2A4 的扰动模拟 执行时间：58.93918251991272 秒
# ==========Use tf is : SLC40A1 =============
# 已完成 SLC40A1 的扰动模拟 执行时间：59.28484606742859 秒
# ==========Use tf is : SLC4A1 =============
# 已完成 SLC4A1 的扰动模拟 执行时间：60.18830108642578 秒
# ==========Use tf is : SLC4A10 =============
# 已完成 SLC4A10 的扰动模拟 执行时间：59.08224391937256 秒
# ==========Use tf is : SLC4A1AP =============
# 已完成 SLC4A1AP 的扰动模拟 执行时间：59.435508728027344 秒
# ==========Use tf is : SLC7A7 =============
# 已完成 SLC7A7 的扰动模拟 执行时间：58.774434089660645 秒
# ==========Use tf is : SLC8A1 =============
# 已完成 SLC8A1 的扰动模拟 执行时间：59.924180030822754 秒
# ==========Use tf is : SLCO2A1 =============
# 已完成 SLCO2A1 的扰动模拟 执行时间：59.035425424575806 秒
# ==========Use tf is : SLPI =============
# 已完成 SLPI 的扰动模拟 执行时间：59.1541793346405 秒
# ==========Use tf is : SMAD3 =============
# 已完成 SMAD3 的扰动模拟 执行时间：59.38871240615845 秒
# ==========Use tf is : SMAD7 =============
# 已完成 SMAD7 的扰动模拟 执行时间：59.24595618247986 秒
# ==========Use tf is : SMARCA1 =============
# 已完成 SMARCA1 的扰动模拟 执行时间：59.263349771499634 秒
# ==========Use tf is : SNCA =============
# 已完成 SNCA 的扰动模拟 执行时间：58.89161515235901 秒
# ==========Use tf is : SNX9 =============
# 已完成 SNX9 的扰动模拟 执行时间：59.06328105926514 秒
# ==========Use tf is : SOCS2 =============
# 已完成 SOCS2 的扰动模拟 执行时间：59.07875609397888 秒
# ==========Use tf is : SORBS1 =============
# 已完成 SORBS1 的扰动模拟 执行时间：59.19359540939331 秒
# ==========Use tf is : SOX5 =============
# 已完成 SOX5 的扰动模拟 执行时间：59.154520988464355 秒
# ==========Use tf is : SP4 =============
# 已完成 SP4 的扰动模拟 执行时间：59.04362440109253 秒
# ==========Use tf is : SPAST =============
# 已完成 SPAST 的扰动模拟 执行时间：59.62199854850769 秒
# ==========Use tf is : SPIB =============
# 已完成 SPIB 的扰动模拟 执行时间：59.410922050476074 秒
# ==========Use tf is : SPP1 =============
# 已完成 SPP1 的扰动模拟 执行时间：59.25337219238281 秒
# ==========Use tf is : SPTA1 =============
# 已完成 SPTA1 的扰动模拟 执行时间：59.102877378463745 秒
# ==========Use tf is : SPTAN1 =============
# 已完成 SPTAN1 的扰动模拟 执行时间：59.25178289413452 秒
# ==========Use tf is : SRGN =============
# 已完成 SRGN 的扰动模拟 执行时间：59.27691197395325 秒
# ==========Use tf is : SSR4 =============
# 已完成 SSR4 的扰动模拟 执行时间：59.22208213806152 秒
# ==========Use tf is : SSX2IP =============
# 已完成 SSX2IP 的扰动模拟 执行时间：59.70538687705994 秒
# ==========Use tf is : STAMBPL1 =============
# 已完成 STAMBPL1 的扰动模拟 执行时间：58.944878578186035 秒
# ==========Use tf is : STAP1 =============
# 已完成 STAP1 的扰动模拟 执行时间：58.782630443573 秒
# ==========Use tf is : STAT1 =============
# 已完成 STAT1 的扰动模拟 执行时间：59.30477261543274 秒
# ==========Use tf is : STAT4 =============
# 已完成 STAT4 的扰动模拟 执行时间：59.00907516479492 秒
# ==========Use tf is : STK17A =============
# 已完成 STK17A 的扰动模拟 执行时间：58.62838006019592 秒
# ==========Use tf is : SYAP1 =============
# 已完成 SYAP1 的扰动模拟 执行时间：59.57277774810791 秒
# ==========Use tf is : SYNE1 =============
# 已完成 SYNE1 的扰动模拟 执行时间：59.29255270957947 秒
# ==========Use tf is : SYNE2 =============
# 已完成 SYNE2 的扰动模拟 执行时间：58.8717405796051 秒
# ==========Use tf is : TADA3 =============
# 已完成 TADA3 的扰动模拟 执行时间：59.27520704269409 秒
# ==========Use tf is : TAF9B =============
# 已完成 TAF9B 的扰动模拟 执行时间：59.59161734580994 秒
# ==========Use tf is : TBC1D4 =============
# 已完成 TBC1D4 的扰动模拟 执行时间：60.36557865142822 秒
# ==========Use tf is : TBL1X =============
# 已完成 TBL1X 的扰动模拟 执行时间：60.39295768737793 秒
# ==========Use tf is : TBX21 =============
# 已完成 TBX21 的扰动模拟 执行时间：60.430076360702515 秒
# ==========Use tf is : TCAF1 =============
# 已完成 TCAF1 的扰动模拟 执行时间：60.12782144546509 秒
# ==========Use tf is : TCF4 =============
# 已完成 TCF4 的扰动模拟 执行时间：60.83953833580017 秒
# ==========Use tf is : TCF7 =============
# 已完成 TCF7 的扰动模拟 执行时间：60.39349913597107 秒
# ==========Use tf is : TCHP =============
# 已完成 TCHP 的扰动模拟 执行时间：60.592803955078125 秒
# ==========Use tf is : TCL1A =============
# 已完成 TCL1A 的扰动模拟 执行时间：60.13408017158508 秒
# ==========Use tf is : TDRD3 =============
# 已完成 TDRD3 的扰动模拟 执行时间：59.28928756713867 秒
# ==========Use tf is : TEAD1 =============
# 已完成 TEAD1 的扰动模拟 执行时间：59.744887351989746 秒
# ==========Use tf is : TF =============
# 已完成 TF 的扰动模拟 执行时间：59.20831871032715 秒
# ==========Use tf is : TFPI =============
# 已完成 TFPI 的扰动模拟 执行时间：59.674906492233276 秒
# ==========Use tf is : TFRC =============
# 已完成 TFRC 的扰动模拟 执行时间：59.1397647857666 秒
# ==========Use tf is : TGFBR1 =============
# 已完成 TGFBR1 的扰动模拟 执行时间：59.43579387664795 秒
# ==========Use tf is : TGFBR2 =============
# 已完成 TGFBR2 的扰动模拟 执行时间：58.657970666885376 秒
# ==========Use tf is : THBS1 =============
# 已完成 THBS1 的扰动模拟 执行时间：59.79312992095947 秒
# ==========Use tf is : THRB =============
# 已完成 THRB 的扰动模拟 执行时间：59.21908092498779 秒
# ==========Use tf is : TLE1 =============
# 已完成 TLE1 的扰动模拟 执行时间：58.847487926483154 秒
# ==========Use tf is : TLR4 =============
# 已完成 TLR4 的扰动模拟 执行时间：58.80148005485535 秒
# ==========Use tf is : TLR5 =============
# 已完成 TLR5 的扰动模拟 执行时间：59.57840943336487 秒
# ==========Use tf is : TLR8 =============
# 已完成 TLR8 的扰动模拟 执行时间：59.29646944999695 秒
# ==========Use tf is : TMPRSS11D =============
# 已完成 TMPRSS11D 的扰动模拟 执行时间：59.19528388977051 秒
# ==========Use tf is : TMSB4X =============
# 已完成 TMSB4X 的扰动模拟 执行时间：59.67762756347656 秒
# ==========Use tf is : TNC =============
# 已完成 TNC 的扰动模拟 执行时间：59.147528648376465 秒
# ==========Use tf is : TNF =============
# 已完成 TNF 的扰动模拟 执行时间：59.09399962425232 秒
# ==========Use tf is : TNFAIP2 =============
# 已完成 TNFAIP2 的扰动模拟 执行时间：58.980040550231934 秒
# ==========Use tf is : TNFAIP3 =============
# 已完成 TNFAIP3 的扰动模拟 执行时间：58.86083698272705 秒
# ==========Use tf is : TNFRSF13B =============
# 已完成 TNFRSF13B 的扰动模拟 执行时间：58.83269119262695 秒
# ==========Use tf is : TNFRSF17 =============
# 已完成 TNFRSF17 的扰动模拟 执行时间：59.53693079948425 秒
# ==========Use tf is : TNFRSF1B =============
# 已完成 TNFRSF1B 的扰动模拟 执行时间：59.49473810195923 秒
# ==========Use tf is : TNFRSF21 =============
# 已完成 TNFRSF21 的扰动模拟 执行时间：58.96691823005676 秒
# ==========Use tf is : TNFSF10 =============
# 已完成 TNFSF10 的扰动模拟 执行时间：59.35728931427002 秒
# ==========Use tf is : TNIK =============
# 已完成 TNIK 的扰动模拟 执行时间：58.761934757232666 秒
# ==========Use tf is : TNKS =============
# 已完成 TNKS 的扰动模拟 执行时间：59.63292121887207 秒
# ==========Use tf is : TNNI2 =============
# 已完成 TNNI2 的扰动模拟 执行时间：58.852800369262695 秒
# ==========Use tf is : TNRC6C =============
# 已完成 TNRC6C 的扰动模拟 执行时间：59.264885902404785 秒
# ==========Use tf is : TOB1 =============
# 已完成 TOB1 的扰动模拟 执行时间：59.73637890815735 秒
# ==========Use tf is : TOP2A =============
# 已完成 TOP2A 的扰动模拟 执行时间：59.38846397399902 秒
# ==========Use tf is : TOX =============
# 已完成 TOX 的扰动模拟 执行时间：59.10993456840515 秒
# ==========Use tf is : TP53INP1 =============
# 已完成 TP53INP1 的扰动模拟 执行时间：59.10163927078247 秒
# ==========Use tf is : TP53INP2 =============
# 已完成 TP53INP2 的扰动模拟 执行时间：58.783878564834595 秒
# ==========Use tf is : TPD52 =============
# 已完成 TPD52 的扰动模拟 执行时间：58.8158745765686 秒
# ==========Use tf is : TPM1 =============
# 已完成 TPM1 的扰动模拟 执行时间：59.29658269882202 秒
# ==========Use tf is : TPSAB1 =============
# 已完成 TPSAB1 的扰动模拟 执行时间：59.05112814903259 秒
# ==========Use tf is : TPSB2 =============
# 已完成 TPSB2 的扰动模拟 执行时间：59.21817922592163 秒
# ==========Use tf is : TRAF1 =============
# 已完成 TRAF1 的扰动模拟 执行时间：58.663291931152344 秒
# ==========Use tf is : TRAF6 =============
# 已完成 TRAF6 的扰动模拟 执行时间：59.066840410232544 秒
# ==========Use tf is : TRAT1 =============
# 已完成 TRAT1 的扰动模拟 执行时间：58.80304837226868 秒
# ==========Use tf is : TREM1 =============
# 已完成 TREM1 的扰动模拟 执行时间：59.586392879486084 秒
# ==========Use tf is : TRH =============
# 已完成 TRH 的扰动模拟 执行时间：59.42457604408264 秒
# ==========Use tf is : TRIB2 =============
# 已完成 TRIB2 的扰动模拟 执行时间：58.888232707977295 秒
# ==========Use tf is : TRIM23 =============
# 已完成 TRIM23 的扰动模拟 执行时间：59.10408616065979 秒
# ==========Use tf is : TRPC1 =============
# 已完成 TRPC1 的扰动模拟 执行时间：59.01007676124573 秒
# ==========Use tf is : TRPS1 =============
# 已完成 TRPS1 的扰动模拟 执行时间：59.3622624874115 秒
# ==========Use tf is : TSC22D1 =============
# 已完成 TSC22D1 的扰动模拟 执行时间：59.1223840713501 秒
# ==========Use tf is : TSLP =============
# 已完成 TSLP 的扰动模拟 执行时间：59.453941822052 秒
# ==========Use tf is : TTN =============
# 已完成 TTN 的扰动模拟 执行时间：59.24365305900574 秒
# ==========Use tf is : TUBB1 =============
# 已完成 TUBB1 的扰动模拟 执行时间：59.39000749588013 秒
# ==========Use tf is : TWISTNB =============
# 已完成 TWISTNB 的扰动模拟 执行时间：59.328304052352905 秒
# ==========Use tf is : TXK =============
# 已完成 TXK 的扰动模拟 执行时间：58.989060401916504 秒
# ==========Use tf is : TXNDC5 =============
# 已完成 TXNDC5 的扰动模拟 执行时间：59.384973764419556 秒
# ==========Use tf is : TXNIP =============
# 已完成 TXNIP 的扰动模拟 执行时间：59.2212336063385 秒
# ==========Use tf is : TYROBP =============
# 已完成 TYROBP 的扰动模拟 执行时间：59.76014065742493 秒
# ==========Use tf is : UACA =============
# 已完成 UACA 的扰动模拟 执行时间：59.43295621871948 秒
# ==========Use tf is : UBASH3B =============
# 已完成 UBASH3B 的扰动模拟 执行时间：58.92877197265625 秒
# ==========Use tf is : USP28 =============
# 已完成 USP28 的扰动模拟 执行时间：59.01486325263977 秒
# ==========Use tf is : USP53 =============
# 已完成 USP53 的扰动模拟 执行时间：59.286909103393555 秒
# ==========Use tf is : UTP15 =============
# 已完成 UTP15 的扰动模拟 执行时间：58.56639552116394 秒
# ==========Use tf is : VAPB =============
# 已完成 VAPB 的扰动模拟 执行时间：59.2537944316864 秒
# ==========Use tf is : VCAM1 =============
# 已完成 VCAM1 的扰动模拟 执行时间：59.168461561203 秒
# ==========Use tf is : VCAN =============
# 已完成 VCAN 的扰动模拟 执行时间：59.37528467178345 秒
# ==========Use tf is : VIM =============
# 已完成 VIM 的扰动模拟 执行时间：59.26340985298157 秒
# ==========Use tf is : VMP1 =============
# 已完成 VMP1 的扰动模拟 执行时间：58.85339975357056 秒
# ==========Use tf is : VNN1 =============
# 已完成 VNN1 的扰动模拟 执行时间：59.22308135032654 秒
# ==========Use tf is : WNT10A =============
# 已完成 WNT10A 的扰动模拟 执行时间：58.919177770614624 秒
# ==========Use tf is : WWP1 =============
# 已完成 WWP1 的扰动模拟 执行时间：59.079190254211426 秒
# ==========Use tf is : XAF1 =============
# 已完成 XAF1 的扰动模拟 执行时间：59.12374520301819 秒
# ==========Use tf is : XCL1 =============
# 已完成 XCL1 的扰动模拟 执行时间：59.30788993835449 秒
# ==========Use tf is : ZAP70 =============
# 已完成 ZAP70 的扰动模拟 执行时间：58.914504289627075 秒
# ==========Use tf is : ZBTB16 =============
# 已完成 ZBTB16 的扰动模拟 执行时间：58.94589185714722 秒
# ==========Use tf is : ZBTB18 =============
# 已完成 ZBTB18 的扰动模拟 执行时间：58.90207648277283 秒
# ==========Use tf is : ZBTB20 =============
# 已完成 ZBTB20 的扰动模拟 执行时间：58.959826707839966 秒
# ==========Use tf is : ZBTB40 =============
# 已完成 ZBTB40 的扰动模拟 执行时间：59.011937856674194 秒
# ==========Use tf is : ZBTB6 =============
# 已完成 ZBTB6 的扰动模拟 执行时间：59.12178683280945 秒
# ==========Use tf is : ZC3H12A =============
# 已完成 ZC3H12A 的扰动模拟 执行时间：59.219268560409546 秒
# ==========Use tf is : ZEB1 =============
# 已完成 ZEB1 的扰动模拟 执行时间：58.896769285202026 秒
# ==========Use tf is : ZFHX3 =============
# 已完成 ZFHX3 的扰动模拟 执行时间：59.5891547203064 秒
# ==========Use tf is : ZFYVE16 =============
# 已完成 ZFYVE16 的扰动模拟 执行时间：58.63284730911255 秒
# ==========Use tf is : ZKSCAN8 =============
# 已完成 ZKSCAN8 的扰动模拟 执行时间：59.53421998023987 秒
# ==========Use tf is : ZNF143 =============
# 已完成 ZNF143 的扰动模拟 执行时间：59.19195032119751 秒
# ==========Use tf is : ZNF174 =============
# 已完成 ZNF174 的扰动模拟 执行时间：59.33752965927124 秒
# ==========Use tf is : ZNF25 =============
# 已完成 ZNF25 的扰动模拟 执行时间：59.098063230514526 秒
# ==========Use tf is : ZNF704 =============
# 已完成 ZNF704 的扰动模拟 执行时间：58.67830967903137 秒
# ==========Use tf is : ZNFX1 =============
# 已完成 ZNFX1 的扰动模拟 执行时间：59.18284273147583 秒

# %%
# 2. 为每个TF计算扰动分数
print("开始计算每个转录因子的扰动分数...")
perturbation_scores = {}

for tf, shift_data in perturbation_results.items():  
    print(f"正在处理转录因子: {tf}")
    dev = Oracle_development_module()  
    dev.load_differentiation_reference_data(gradient_object=gradient)  
    oracle.delta_embedding = shift_data  
    dev.load_perturb_simulation_data(oracle_object=oracle,   
                                     cell_idx_use=cell_idx_use,  
                                     name=f"{tf}_perturbation")  
    
    # 可选：诊断步骤，检查向量形状
    # 如果CellOracle版本允许，可以尝试打印内部向量维度进行确认
    # print(f"TF {tf} 的流程数据已加载。")
    
    # 计算内积分数  
    dev.calculate_inner_product()
    dev.calculate_digitized_ip(n_bins=10) 
    perturbation_scores[tf] = dev.inner_product_df['score'].sum()  
    print(f"  {tf} 的扰动分数: {perturbation_scores[tf]:.4f}")

# 3. 按扰动分数排序并输出结果  
print("\n关键TF排序（按扰动分数降序）:")  
sorted_tfs = sorted(perturbation_scores.items(), key=lambda x: x[1], reverse=True)  
for i, (tf, score) in enumerate(sorted_tfs[:10]):  
    print(f"{i+1}. {tf}: {score:.4f}")
# Out:
# 开始计算每个转录因子的扰动分数...
# 正在处理转录因子: A2M
#   A2M 的扰动分数: 0.1380
# 正在处理转录因子: ABCA1
#   ABCA1 的扰动分数: -4.6460
# 正在处理转录因子: ABCB1
#   ABCB1 的扰动分数: 7.1035
# 正在处理转录因子: ABCC2
#   ABCC2 的扰动分数: 0.4382
# 正在处理转录因子: ABI2
#   ABI2 的扰动分数: 11.5126
# 正在处理转录因子: ABI3
#   ABI3 的扰动分数: -0.4081
# 正在处理转录因子: ABLIM1
#   ABLIM1 的扰动分数: 2.0881
# 正在处理转录因子: ACVR2A
#   ACVR2A 的扰动分数: 0.7314
# 正在处理转录因子: ADM
#   ADM 的扰动分数: 0.2710
# 正在处理转录因子: AFAP1
#   AFAP1 的扰动分数: 0.3230
# 正在处理转录因子: AFDN
#   AFDN 的扰动分数: 0.3626
# 正在处理转录因子: AGL
#   AGL 的扰动分数: 10.2714
# 正在处理转录因子: AHNAK
#   AHNAK 的扰动分数: -37.2623
# 正在处理转录因子: AHSP
#   AHSP 的扰动分数: -0.5585
# 正在处理转录因子: AIM2
#   AIM2 的扰动分数: 0.0952
# 正在处理转录因子: AKAP12
#   AKAP12 的扰动分数: 0.2738
# 正在处理转录因子: AKAP2
#   AKAP2 的扰动分数: 4.1344
# 正在处理转录因子: ALAS2
#   ALAS2 的扰动分数: -0.3184
# 正在处理转录因子: ALMS1
#   ALMS1 的扰动分数: 1.6702
# 正在处理转录因子: ALOX5
#   ALOX5 的扰动分数: -15.1206
# 正在处理转录因子: AMMECR1
#   AMMECR1 的扰动分数: -0.0819
# 正在处理转录因子: ANKH
#   ANKH 的扰动分数: -1.2732
# 正在处理转录因子: ANXA1
#   ANXA1 的扰动分数: -20.7825
# 正在处理转录因子: APBB1
#   APBB1 的扰动分数: 0.1480
# 正在处理转录因子: APC
#   APC 的扰动分数: -0.0534
# 正在处理转录因子: APOC1
#   APOC1 的扰动分数: 0.1078
# 正在处理转录因子: APOE
#   APOE 的扰动分数: -0.4195
# 正在处理转录因子: AQP9
#   AQP9 的扰动分数: -0.2862
# 正在处理转录因子: AREG
#   AREG 的扰动分数: 16.4109
# 正在处理转录因子: ARHGAP21
#   ARHGAP21 的扰动分数: -1.3050
# 正在处理转录因子: ARHGAP22
#   ARHGAP22 的扰动分数: 0.9382
# 正在处理转录因子: ARHGAP24
#   ARHGAP24 的扰动分数: -0.5964
# 正在处理转录因子: ARID4A
#   ARID4A 的扰动分数: -2.8203
# 正在处理转录因子: ARID5B
#   ARID5B 的扰动分数: -1.2823
# 正在处理转录因子: ARNTL
#   ARNTL 的扰动分数: -3.9815
# 正在处理转录因子: ASPM
#   ASPM 的扰动分数: -1.2223
# 正在处理转录因子: ATF1
#   ATF1 的扰动分数: 15.0783
# 正在处理转录因子: ATF3
#   ATF3 的扰动分数: -24.4337
# 正在处理转录因子: ATM
#   ATM 的扰动分数: -15.3168
# 正在处理转录因子: ATP2B1
#   ATP2B1 的扰动分数: -9.5667
# 正在处理转录因子: AXIN2
#   AXIN2 的扰动分数: 0.0429
# 正在处理转录因子: AZU1
#   AZU1 的扰动分数: 5.7564
# 正在处理转录因子: B2M
#   B2M 的扰动分数: -28.8857
# 正在处理转录因子: BACH2
#   BACH2 的扰动分数: -1.4078
# 正在处理转录因子: BAG2
#   BAG2 的扰动分数: 1.5054
# 正在处理转录因子: BANK1
#   BANK1 的扰动分数: 0.5407
# 正在处理转录因子: BATF
#   BATF 的扰动分数: -1.2004
# 正在处理转录因子: BATF3
#   BATF3 的扰动分数: 0.4001
# 正在处理转录因子: BCL10
#   BCL10 的扰动分数: 0.4833
# 正在处理转录因子: BCL11B
#   BCL11B 的扰动分数: -3.8932
# 正在处理转录因子: BCL2
#   BCL2 的扰动分数: 0.7629
# 正在处理转录因子: BCL2A1
#   BCL2A1 的扰动分数: -7.8041
# 正在处理转录因子: BCL2L11
#   BCL2L11 的扰动分数: -2.0378
# 正在处理转录因子: BCL6
#   BCL6 的扰动分数: -28.5019
# 正在处理转录因子: BCL9L
#   BCL9L 的扰动分数: -0.1337
# 正在处理转录因子: BCOR
#   BCOR 的扰动分数: -2.8530
# 正在处理转录因子: BGLAP
#   BGLAP 的扰动分数: 3.2866
# 正在处理转录因子: BIN1
#   BIN1 的扰动分数: 0.1720
# 正在处理转录因子: BIRC3
#   BIRC3 的扰动分数: -13.9510
# 正在处理转录因子: BLK
#   BLK 的扰动分数: 0.1368
# 正在处理转录因子: BMF
#   BMF 的扰动分数: -1.1948
# 正在处理转录因子: BMPR2
#   BMPR2 的扰动分数: -2.7218
# 正在处理转录因子: BUB1B
#   BUB1B 的扰动分数: 2.4595
# 正在处理转录因子: C15orf40
#   C15orf40 的扰动分数: 1.1790
# 正在处理转录因子: C17orf80
#   C17orf80 的扰动分数: 3.1622
# 正在处理转录因子: C1QA
#   C1QA 的扰动分数: -1.2146
# 正在处理转录因子: C1QC
#   C1QC 的扰动分数: 0.0628
# 正在处理转录因子: C3AR1
#   C3AR1 的扰动分数: -1.0339
# 正在处理转录因子: C5AR1
#   C5AR1 的扰动分数: -4.7011
# 正在处理转录因子: CA1
#   CA1 的扰动分数: -0.0966
# 正在处理转录因子: CA2
#   CA2 的扰动分数: -4.0472
# 正在处理转录因子: CACNA1A
#   CACNA1A 的扰动分数: -0.2434
# 正在处理转录因子: CADM1
#   CADM1 的扰动分数: 0.7080
# 正在处理转录因子: CAMK2D
#   CAMK2D 的扰动分数: -10.0555
# 正在处理转录因子: CAMK4
#   CAMK4 的扰动分数: -0.9384
# 正在处理转录因子: CAMP
#   CAMP 的扰动分数: 0.0533
# 正在处理转录因子: CASP8
#   CASP8 的扰动分数: -0.4277
# 正在处理转录因子: CAV1
#   CAV1 的扰动分数: 11.7577
# 正在处理转录因子: CAVIN1
#   CAVIN1 的扰动分数: -0.1482
# 正在处理转录因子: CCL5
#   CCL5 的扰动分数: -1.2836
# 正在处理转录因子: CCNF
#   CCNF 的扰动分数: -0.4006
# 正在处理转录因子: CCR1
#   CCR1 的扰动分数: -4.5611
# 正在处理转录因子: CCR5
#   CCR5 的扰动分数: -0.5115
# 正在处理转录因子: CCR6
#   CCR6 的扰动分数: 0.1148
# 正在处理转录因子: CCR7
#   CCR7 的扰动分数: -1.9365
# 正在处理转录因子: CD14
#   CD14 的扰动分数: -27.5101
# 正在处理转录因子: CD160
#   CD160 的扰动分数: 0.0754
# 正在处理转录因子: CD1D
#   CD1D 的扰动分数: -3.5651
# 正在处理转录因子: CD2
#   CD2 的扰动分数: -6.6551
# 正在处理转录因子: CD22
#   CD22 的扰动分数: 0.3530
# 正在处理转录因子: CD24
#   CD24 的扰动分数: 2.1891
# 正在处理转录因子: CD247
#   CD247 的扰动分数: -3.6128
# 正在处理转录因子: CD274
#   CD274 的扰动分数: 0.1367
# 正在处理转录因子: CD28
#   CD28 的扰动分数: -2.3118
# 正在处理转录因子: CD34
#   CD34 的扰动分数: 22.6840
# 正在处理转录因子: CD36
#   CD36 的扰动分数: -16.1287
# 正在处理转录因子: CD3D
#   CD3D 的扰动分数: -5.3769
# 正在处理转录因子: CD3E
#   CD3E 的扰动分数: -4.3052
# 正在处理转录因子: CD3G
#   CD3G 的扰动分数: -5.9844
# 正在处理转录因子: CD40LG
#   CD40LG 的扰动分数: -0.9983
# 正在处理转录因子: CD47
#   CD47 的扰动分数: 5.0550
# 正在处理转录因子: CD48
#   CD48 的扰动分数: -12.3357
# 正在处理转录因子: CD5
#   CD5 的扰动分数: -0.2522
# 正在处理转录因子: CD6
#   CD6 的扰动分数: -0.7424
# 正在处理转录因子: CD7
#   CD7 的扰动分数: -0.4465
# 正在处理转录因子: CD74
#   CD74 的扰动分数: 5.0036
# 正在处理转录因子: CD79A
#   CD79A 的扰动分数: 0.3479
# 正在处理转录因子: CD79B
#   CD79B 的扰动分数: 4.0664
# 正在处理转录因子: CD86
#   CD86 的扰动分数: -6.0688
# 正在处理转录因子: CD8A
#   CD8A 的扰动分数: -2.1078
# 正在处理转录因子: CD8B
#   CD8B 的扰动分数: -1.0391
# 正在处理转录因子: CDC42EP3
#   CDC42EP3 的扰动分数: -9.4879
# 正在处理转录因子: CDK5R1
#   CDK5R1 的扰动分数: 0.1811
# 正在处理转录因子: CDKN1A
#   CDKN1A 的扰动分数: -16.7864
# 正在处理转录因子: CDKN2D
#   CDKN2D 的扰动分数: -3.9932
# 正在处理转录因子: CEBPD
#   CEBPD 的扰动分数: -41.2032
# 正在处理转录因子: CENPE
#   CENPE 的扰动分数: 5.6026
# 正在处理转录因子: CENPF
#   CENPF 的扰动分数: 5.2871
# 正在处理转录因子: CEP120
#   CEP120 的扰动分数: -0.5656
# 正在处理转录因子: CEP128
#   CEP128 的扰动分数: 1.4945
# 正在处理转录因子: CEP135
#   CEP135 的扰动分数: 0.7324
# 正在处理转录因子: CEP290
#   CEP290 的扰动分数: 4.7465
# 正在处理转录因子: CEP70
#   CEP70 的扰动分数: 4.9028
# 正在处理转录因子: CES1
#   CES1 的扰动分数: -11.8813
# 正在处理转录因子: CFD
#   CFD 的扰动分数: -15.4789
# 正在处理转录因子: CHD7
#   CHD7 的扰动分数: -24.3523
# 正在处理转录因子: CHI3L2
#   CHI3L2 的扰动分数: -0.2381
# 正在处理转录因子: CHIC2
#   CHIC2 的扰动分数: 0.8720
# 正在处理转录因子: CHRNA7
#   CHRNA7 的扰动分数: 0.9044
# 正在处理转录因子: CHST15
#   CHST15 的扰动分数: -1.4393
# 正在处理转录因子: CITED2
#   CITED2 的扰动分数: -2.7031
# 正在处理转录因子: CKB
#   CKB 的扰动分数: 1.5643
# 正在处理转录因子: CLDN3
#   CLDN3 的扰动分数: 0.0436
# 正在处理转录因子: CLEC4A
#   CLEC4A 的扰动分数: -3.9634
# 正在处理转录因子: CLEC7A
#   CLEC7A 的扰动分数: -2.1042
# 正在处理转录因子: CLIC2
#   CLIC2 的扰动分数: 1.4822
# 正在处理转录因子: CLOCK
#   CLOCK 的扰动分数: -0.5513
# 正在处理转录因子: CMC1
#   CMC1 的扰动分数: 4.2760
# 正在处理转录因子: COL1A2
#   COL1A2 的扰动分数: 0.0995
# 正在处理转录因子: COL4A3
#   COL4A3 的扰动分数: 0.3017
# 正在处理转录因子: COMMD3
#   COMMD3 的扰动分数: 9.2055
# 正在处理转录因子: CPEB4
#   CPEB4 的扰动分数: -7.5095
# 正在处理转录因子: CPNE5
#   CPNE5 的扰动分数: 0.7973
# 正在处理转录因子: CPVL
#   CPVL 的扰动分数: -10.0427
# 正在处理转录因子: CREB3
#   CREB3 的扰动分数: 1.0617
# 正在处理转录因子: CREB5
#   CREB5 的扰动分数: 4.3281
# 正在处理转录因子: CREBL2
#   CREBL2 的扰动分数: -0.3646
# 正在处理转录因子: CREM
#   CREM 的扰动分数: -0.6598
# 正在处理转录因子: CRY1
#   CRY1 的扰动分数: 0.7156
# 正在处理转录因子: CSF1
#   CSF1 的扰动分数: -0.1369
# 正在处理转录因子: CSF1R
#   CSF1R 的扰动分数: -9.2396
# 正在处理转录因子: CSNK1G1
#   CSNK1G1 的扰动分数: 0.8714
# 正在处理转录因子: CST3
#   CST3 的扰动分数: -36.0846
# 正在处理转录因子: CSTA
#   CSTA 的扰动分数: -47.1395
# 正在处理转录因子: CTGF
#   CTGF 的扰动分数: 0.1405
# 正在处理转录因子: CTLA4
#   CTLA4 的扰动分数: 0.0398
# 正在处理转录因子: CTSG
#   CTSG 的扰动分数: 10.2822
# 正在处理转录因子: CTSH
#   CTSH 的扰动分数: -38.1232
# 正在处理转录因子: CTSL
#   CTSL 的扰动分数: -7.7181
# 正在处理转录因子: CTSS
#   CTSS 的扰动分数: -43.8804
# 正在处理转录因子: CX3CR1
#   CX3CR1 的扰动分数: -1.4698
# 正在处理转录因子: CXADR
#   CXADR 的扰动分数: 0.1730
# 正在处理转录因子: CXCL10
#   CXCL10 的扰动分数: 0.2370
# 正在处理转录因子: CXCL12
#   CXCL12 的扰动分数: 0.2886
# 正在处理转录因子: CXCL16
#   CXCL16 的扰动分数: -1.1014
# 正在处理转录因子: CXCL2
#   CXCL2 的扰动分数: 5.1830
# 正在处理转录因子: CXCL3
#   CXCL3 的扰动分数: 1.2948
# 正在处理转录因子: CXCL8
#   CXCL8 的扰动分数: -36.5135
# 正在处理转录因子: CYBB
#   CYBB 的扰动分数: -37.8114
# 正在处理转录因子: CYFIP2
#   CYFIP2 的扰动分数: 7.8292
# 正在处理转录因子: CYLD
#   CYLD 的扰动分数: 6.2676
# 正在处理转录因子: CYP1B1
#   CYP1B1 的扰动分数: -1.4227
# 正在处理转录因子: CYP7B1
#   CYP7B1 的扰动分数: 2.9646
# 正在处理转录因子: CYSLTR2
#   CYSLTR2 的扰动分数: 3.7490
# 正在处理转录因子: DACH1
#   DACH1 的扰动分数: -2.9367
# 正在处理转录因子: DCN
#   DCN 的扰动分数: 0.1055
# 正在处理转录因子: DDIT3
#   DDIT3 的扰动分数: -4.9098
# 正在处理转录因子: DDIT4L
#   DDIT4L 的扰动分数: 0.1224
# 正在处理转录因子: DDX58
#   DDX58 的扰动分数: -0.8887
# 正在处理转录因子: DEFB1
#   DEFB1 的扰动分数: -2.4206
# 正在处理转录因子: DHRS9
#   DHRS9 的扰动分数: -1.2417
# 正在处理转录因子: DKK1
#   DKK1 的扰动分数: 0.0270
# 正在处理转录因子: DLGAP5
#   DLGAP5 的扰动分数: -2.7669
# 正在处理转录因子: DLK1
#   DLK1 的扰动分数: 0.2183
# 正在处理转录因子: DMTN
#   DMTN 的扰动分数: -0.0313
# 正在处理转录因子: DNAH8
#   DNAH8 的扰动分数: 0.1453
# 正在处理转录因子: DNAJB1
#   DNAJB1 的扰动分数: -6.2927
# 正在处理转录因子: DNAJB9
#   DNAJB9 的扰动分数: 0.5920
# 正在处理转录因子: DNTT
#   DNTT 的扰动分数: 4.8775
# 正在处理转录因子: DUSP6
#   DUSP6 的扰动分数: 6.0573
# 正在处理转录因子: DYNC2H1
#   DYNC2H1 的扰动分数: 0.4351
# 正在处理转录因子: DYRK2
#   DYRK2 的扰动分数: 1.0115
# 正在处理转录因子: E2F7
#   E2F7 的扰动分数: -2.6191
# 正在处理转录因子: EAF1
#   EAF1 的扰动分数: -3.9281
# 正在处理转录因子: EBF1
#   EBF1 的扰动分数: 1.1664
# 正在处理转录因子: EBF3
#   EBF3 的扰动分数: 0.2652
# 正在处理转录因子: EFHC1
#   EFHC1 的扰动分数: 1.5897
# 正在处理转录因子: EGR1
#   EGR1 的扰动分数: -1.2001
# 正在处理转录因子: EGR2
#   EGR2 的扰动分数: -5.3620
# 正在处理转录因子: EGR3
#   EGR3 的扰动分数: -0.2473
# 正在处理转录因子: ELANE
#   ELANE 的扰动分数: -0.7635
# 正在处理转录因子: ELAVL4
#   ELAVL4 的扰动分数: 0.6664
# 正在处理转录因子: ELL2
#   ELL2 的扰动分数: 1.7155
# 正在处理转录因子: EMP1
#   EMP1 的扰动分数: 0.4603
# 正在处理转录因子: EN1
#   EN1 的扰动分数: 3.0454
# 正在处理转录因子: ENAH
#   ENAH 的扰动分数: 1.2240
# 正在处理转录因子: EOMES
#   EOMES 的扰动分数: -1.1556
# 正在处理转录因子: EPAS1
#   EPAS1 的扰动分数: 0.7746
# 正在处理转录因子: EPHA2
#   EPHA2 的扰动分数: 0.1430
# 正在处理转录因子: EPHA4
#   EPHA4 的扰动分数: -0.0133
# 正在处理转录因子: EPHB2
#   EPHB2 的扰动分数: -0.6199
# 正在处理转录因子: ERCC4
#   ERCC4 的扰动分数: 1.6032
# 正在处理转录因子: ERCC6
#   ERCC6 的扰动分数: 0.8399
# 正在处理转录因子: EREG
#   EREG 的扰动分数: -14.6323
# 正在处理转录因子: ETS1
#   ETS1 的扰动分数: 13.4512
# 正在处理转录因子: ETV1
#   ETV1 的扰动分数: 0.2638
# 正在处理转录因子: EVI5
#   EVI5 的扰动分数: -22.6150
# 正在处理转录因子: EXD2
#   EXD2 的扰动分数: 1.8583
# 正在处理转录因子: EZR
#   EZR 的扰动分数: -9.0937
# 正在处理转录因子: F13A1
#   F13A1 的扰动分数: -2.5648
# 正在处理转录因子: F2R
#   F2R 的扰动分数: 1.6216
# 正在处理转录因子: FABP4
#   FABP4 的扰动分数: 0.1319
# 正在处理转录因子: FAM20C
#   FAM20C 的扰动分数: -2.9649
# 正在处理转录因子: FAM98A
#   FAM98A 的扰动分数: 4.3663
# 正在处理转录因子: FANCM
#   FANCM 的扰动分数: 2.4921
# 正在处理转录因子: FAS
#   FAS 的扰动分数: -6.9377
# 正在处理转录因子: FBP1
#   FBP1 的扰动分数: -9.6893
# 正在处理转录因子: FBXW7
#   FBXW7 的扰动分数: -10.4670
# 正在处理转录因子: FCER1A
#   FCER1A 的扰动分数: -11.5116
# 正在处理转录因子: FCGR3A
#   FCGR3A 的扰动分数: -1.9358
# 正在处理转录因子: FCN1
#   FCN1 的扰动分数: -25.3417
# 正在处理转录因子: FGFR3
#   FGFR3 的扰动分数: 0.1570
# 正在处理转录因子: FIGNL1
#   FIGNL1 的扰动分数: 1.7619
# 正在处理转录因子: FKBP11
#   FKBP11 的扰动分数: 7.6875
# 正在处理转录因子: FNBP1L
#   FNBP1L 的扰动分数: 0.0007
# 正在处理转录因子: FOS
#   FOS 的扰动分数: -43.7505
# 正在处理转录因子: FOXC1
#   FOXC1 的扰动分数: 7.9298
# 正在处理转录因子: FOXD1
#   FOXD1 的扰动分数: 0.1026
# 正在处理转录因子: FOXL1
#   FOXL1 的扰动分数: 0.0495
# 正在处理转录因子: FOXO1
#   FOXO1 的扰动分数: -1.9194
# 正在处理转录因子: FPR1
#   FPR1 的扰动分数: -1.9359
# 正在处理转录因子: FPR2
#   FPR2 的扰动分数: -3.3217
# 正在处理转录因子: FTH1
#   FTH1 的扰动分数: -38.1872
# 正在处理转录因子: FTL
#   FTL 的扰动分数: -25.1413
# 正在处理转录因子: FYN
#   FYN 的扰动分数: -24.7246
# 正在处理转录因子: GAD1
#   GAD1 的扰动分数: 0.1325
# 正在处理转录因子: GADD45B
#   GADD45B 的扰动分数: -7.0425
# 正在处理转录因子: GANC
#   GANC 的扰动分数: -1.7225
# 正在处理转录因子: GATA2
#   GATA2 的扰动分数: 49.4291
# 正在处理转录因子: GATA3
#   GATA3 的扰动分数: -6.8194
# 正在处理转录因子: GBP2
#   GBP2 的扰动分数: -10.9375
# 正在处理转录因子: GCLM
#   GCLM 的扰动分数: 0.1653
# 正在处理转录因子: GIMAP8
#   GIMAP8 的扰动分数: -1.2791
# 正在处理转录因子: GJA1
#   GJA1 的扰动分数: 0.6543
# 正在处理转录因子: GLI3
#   GLI3 的扰动分数: 0.6428
# 正在处理转录因子: GLIS3
#   GLIS3 的扰动分数: 0.1762
# 正在处理转录因子: GNG2
#   GNG2 的扰动分数: -3.6030
# 正在处理转录因子: GNGT2
#   GNGT2 的扰动分数: 0.0026
# 正在处理转录因子: GNRH1
#   GNRH1 的扰动分数: 0.6434
# 正在处理转录因子: GPX1
#   GPX1 的扰动分数: -7.0596
# 正在处理转录因子: GRAP2
#   GRAP2 的扰动分数: -4.3855
# 正在处理转录因子: GRK5
#   GRK5 的扰动分数: 0.4979
# 正在处理转录因子: GTF2E1
#   GTF2E1 的扰动分数: 0.9448
# 正在处理转录因子: GTF3C1
#   GTF3C1 的扰动分数: 1.8780
# 正在处理转录因子: GYPA
#   GYPA 的扰动分数: -0.6108
# 正在处理转录因子: GYPB
#   GYPB 的扰动分数: -0.5340
# 正在处理转录因子: GZMB
#   GZMB 的扰动分数: -0.5384
# 正在处理转录因子: H1F0
#   H1F0 的扰动分数: 3.9586
# 正在处理转录因子: H3F3B
#   H3F3B 的扰动分数: -0.6256
# 正在处理转录因子: H6PD
#   H6PD 的扰动分数: -0.4966
# 正在处理转录因子: HAUS3
#   HAUS3 的扰动分数: -6.9987
# 正在处理转录因子: HBA1
#   HBA1 的扰动分数: -0.3044
# 正在处理转录因子: HBA2
#   HBA2 的扰动分数: -1.1547
# 正在处理转录因子: HBB
#   HBB 的扰动分数: -1.8401
# 正在处理转录因子: HBD
#   HBD 的扰动分数: 0.2213
# 正在处理转录因子: HBE1
#   HBE1 的扰动分数: -0.5375
# 正在处理转录因子: HBEGF
#   HBEGF 的扰动分数: -11.5799
# 正在处理转录因子: HBG1
#   HBG1 的扰动分数: -0.0329
# 正在处理转录因子: HBG2
#   HBG2 的扰动分数: 0.1230
# 正在处理转录因子: HDAC9
#   HDAC9 的扰动分数: -9.8616
# 正在处理转录因子: HERC5
#   HERC5 的扰动分数: -0.4915
# 正在处理转录因子: HERPUD1
#   HERPUD1 的扰动分数: -10.4328
# 正在处理转录因子: HES1
#   HES1 的扰动分数: 0.3381
# 正在处理转录因子: HIC2
#   HIC2 的扰动分数: 0.7388
# 正在处理转录因子: HIF1A
#   HIF1A 的扰动分数: -33.9765
# 正在处理转录因子: HIPK2
#   HIPK2 的扰动分数: -27.3898
# 正在处理转录因子: HIST1H1B
#   HIST1H1B 的扰动分数: 3.4075
# 正在处理转录因子: HIST1H1D
#   HIST1H1D 的扰动分数: 9.6682
# 正在处理转录因子: HIST1H2AG
#   HIST1H2AG 的扰动分数: 4.4087
# 正在处理转录因子: HIST1H2AJ
#   HIST1H2AJ 的扰动分数: 11.8010
# 正在处理转录因子: HIST1H2AM
#   HIST1H2AM 的扰动分数: 10.5811
# 正在处理转录因子: HIST1H2BG
#   HIST1H2BG 的扰动分数: -4.3756
# 正在处理转录因子: HIST1H4C
#   HIST1H4C 的扰动分数: 20.5623
# 正在处理转录因子: HIVEP1
#   HIVEP1 的扰动分数: -2.8471
# 正在处理转录因子: HLA-DMB
#   HLA-DMB 的扰动分数: 2.5104
# 正在处理转录因子: HLA-DPA1
#   HLA-DPA1 的扰动分数: 1.7478
# 正在处理转录因子: HLA-DPB1
#   HLA-DPB1 的扰动分数: 2.7380
# 正在处理转录因子: HLA-DQA1
#   HLA-DQA1 的扰动分数: 2.0915
# 正在处理转录因子: HLA-DQB1
#   HLA-DQB1 的扰动分数: 0.7694
# 正在处理转录因子: HLA-DRA
#   HLA-DRA 的扰动分数: 2.6044
# 正在处理转录因子: HLA-DRB1
#   HLA-DRB1 的扰动分数: -4.3141
# 正在处理转录因子: HLA-DRB5
#   HLA-DRB5 的扰动分数: -0.1928
# 正在处理转录因子: HLF
#   HLF 的扰动分数: 0.6129
# 正在处理转录因子: HMGB1
#   HMGB1 的扰动分数: 9.6156
# 正在处理转录因子: HMGB2
#   HMGB2 的扰动分数: -0.0367
# 正在处理转录因子: HMMR
#   HMMR 的扰动分数: -0.0858
# 正在处理转录因子: HOPX
#   HOPX 的扰动分数: 8.6842
# 正在处理转录因子: HOXA13
#   HOXA13 的扰动分数: 0.3128
# 正在处理转录因子: HOXA9
#   HOXA9 的扰动分数: -19.2795
# 正在处理转录因子: HRAS
#   HRAS 的扰动分数: 0.7931
# 正在处理转录因子: HSF2
#   HSF2 的扰动分数: -1.4000
# 正在处理转录因子: HSP90B1
#   HSP90B1 的扰动分数: -1.1168
# 正在处理转录因子: HSPA1B
#   HSPA1B 的扰动分数: -8.8543
# 正在处理转录因子: HSPA1L
#   HSPA1L 的扰动分数: 0.4781
# 正在处理转录因子: HSPA5
#   HSPA5 的扰动分数: 0.5732
# 正在处理转录因子: HSPA7
#   HSPA7 的扰动分数: 1.7541
# 正在处理转录因子: HTR2B
#   HTR2B 的扰动分数: 0.4089
# 正在处理转录因子: ICAM1
#   ICAM1 的扰动分数: 0.4626
# 正在处理转录因子: ICOS
#   ICOS 的扰动分数: 0.0126
# 正在处理转录因子: ID1
#   ID1 的扰动分数: 1.8172
# 正在处理转录因子: ID2
#   ID2 的扰动分数: -9.0321
# 正在处理转录因子: ID3
#   ID3 的扰动分数: 0.2700
# 正在处理转录因子: IER3
#   IER3 的扰动分数: -30.6763
# 正在处理转录因子: IFI27
#   IFI27 的扰动分数: 0.1126
# 正在处理转录因子: IFI30
#   IFI30 的扰动分数: -26.7623
# 正在处理转录因子: IFI6
#   IFI6 的扰动分数: -9.2686
# 正在处理转录因子: IFIH1
#   IFIH1 的扰动分数: 1.3560
# 正在处理转录因子: IFIT1
#   IFIT1 的扰动分数: -2.1944
# 正在处理转录因子: IFIT1B
#   IFIT1B 的扰动分数: 0.0038
# 正在处理转录因子: IFIT3
#   IFIT3 的扰动分数: -5.9466
# 正在处理转录因子: IFITM1
#   IFITM1 的扰动分数: -4.3881
# 正在处理转录因子: IFNG
#   IFNG 的扰动分数: -0.3724
# 正在处理转录因子: IGF1
#   IGF1 的扰动分数: 0.2943
# 正在处理转录因子: IGF1R
#   IGF1R 的扰动分数: 14.5755
# 正在处理转录因子: IGF2
#   IGF2 的扰动分数: 0.4121
# 正在处理转录因子: IGFBP5
#   IGFBP5 的扰动分数: 0.0316
# 正在处理转录因子: IGLL5
#   IGLL5 的扰动分数: 0.1454
# 正在处理转录因子: IKZF2
#   IKZF2 的扰动分数: 4.1076
# 正在处理转录因子: IKZF3
#   IKZF3 的扰动分数: -2.3476
# 正在处理转录因子: IL10RA
#   IL10RA 的扰动分数: -7.8870
# 正在处理转录因子: IL12RB2
#   IL12RB2 的扰动分数: 0.3207
# 正在处理转录因子: IL13RA1
#   IL13RA1 的扰动分数: -11.0632
# 正在处理转录因子: IL15
#   IL15 的扰动分数: 0.3990
# 正在处理转录因子: IL18R1
#   IL18R1 的扰动分数: -0.0325
# 正在处理转录因子: IL1B
#   IL1B 的扰动分数: 24.1229
# 正在处理转录因子: IL2RA
#   IL2RA 的扰动分数: 7.2577
# 正在处理转录因子: IL2RB
#   IL2RB 的扰动分数: -1.2883
# 正在处理转录因子: IL32
#   IL32 的扰动分数: -5.3740
# 正在处理转录因子: IL4R
#   IL4R 的扰动分数: -4.2452
# 正在处理转录因子: IL5RA
#   IL5RA 的扰动分数: 1.1729
# 正在处理转录因子: IL6ST
#   IL6ST 的扰动分数: -17.3436
# 正在处理转录因子: IL7R
#   IL7R 的扰动分数: -6.8041
# 正在处理转录因子: ING1
#   ING1 的扰动分数: -2.6719
# 正在处理转录因子: INPP4A
#   INPP4A 的扰动分数: -0.5907
# 正在处理转录因子: INTS2
#   INTS2 的扰动分数: 1.7214
# 正在处理转录因子: IRF1
#   IRF1 的扰动分数: -31.8235
# 正在处理转录因子: IRF4
#   IRF4 的扰动分数: -6.7943
# 正在处理转录因子: IRF8
#   IRF8 的扰动分数: -20.4238
# 正在处理转录因子: IRS2
#   IRS2 的扰动分数: -22.3580
# 正在处理转录因子: ISG15
#   ISG15 的扰动分数: -4.9959
# 正在处理转录因子: ISG20
#   ISG20 的扰动分数: -3.0655
# 正在处理转录因子: ISG20L2
#   ISG20L2 的扰动分数: 3.4054
# 正在处理转录因子: ITGA6
#   ITGA6 的扰动分数: 11.3408
# 正在处理转录因子: ITGAX
#   ITGAX 的扰动分数: -6.8280
# 正在处理转录因子: ITK
#   ITK 的扰动分数: -6.3687
# 正在处理转录因子: JAZF1
#   JAZF1 的扰动分数: -4.7217
# 正在处理转录因子: JCHAIN
#   JCHAIN 的扰动分数: 1.8290
# 正在处理转录因子: JMY
#   JMY 的扰动分数: 1.6546
# 正在处理转录因子: JUN
#   JUN 的扰动分数: -19.5402
# 正在处理转录因子: KAT2B
#   KAT2B 的扰动分数: -19.0446
# 正在处理转录因子: KCTD12
#   KCTD12 的扰动分数: -18.1670
# 正在处理转录因子: KIAA1551
#   KIAA1551 的扰动分数: -8.7078
# 正在处理转录因子: KIF14
#   KIF14 的扰动分数: 0.1387
# 正在处理转录因子: KIFAP3
#   KIFAP3 的扰动分数: 3.0292
# 正在处理转录因子: KIR2DL4
#   KIR2DL4 的扰动分数: -0.0725
# 正在处理转录因子: KLC1
#   KLC1 的扰动分数: -0.8409
# 正在处理转录因子: KLF11
#   KLF11 的扰动分数: -2.2006
# 正在处理转录因子: KLF12
#   KLF12 的扰动分数: -0.1026
# 正在处理转录因子: KLF2
#   KLF2 的扰动分数: -19.3010
# 正在处理转录因子: KLF6
#   KLF6 的扰动分数: -13.4233
# 正在处理转录因子: KLRB1
#   KLRB1 的扰动分数: -1.8718
# 正在处理转录因子: KLRC1
#   KLRC1 的扰动分数: -0.2189
# 正在处理转录因子: KLRC2
#   KLRC2 的扰动分数: -0.2057
# 正在处理转录因子: KLRD1
#   KLRD1 的扰动分数: -0.9458
# 正在处理转录因子: KLRK1
#   KLRK1 的扰动分数: -2.9028
# 正在处理转录因子: KNL1
#   KNL1 的扰动分数: 6.8002
# 正在处理转录因子: KPNA5
#   KPNA5 的扰动分数: 1.3133
# 正在处理转录因子: L3MBTL3
#   L3MBTL3 的扰动分数: -1.8333
# 正在处理转录因子: LAMA4
#   LAMA4 的扰动分数: 0.0487
# 正在处理转录因子: LAT
#   LAT 的扰动分数: -1.4040
# 正在处理转录因子: LBX2
#   LBX2 的扰动分数: 0.6167
# 正在处理转录因子: LCK
#   LCK 的扰动分数: -3.5650
# 正在处理转录因子: LDB1
#   LDB1 的扰动分数: -6.4225
# 正在处理转录因子: LDLR
#   LDLR 的扰动分数: -1.9729
# 正在处理转录因子: LEF1
#   LEF1 的扰动分数: -2.8156
# 正在处理转录因子: LEPR
#   LEPR 的扰动分数: 11.0963
# 正在处理转录因子: LGALS1
#   LGALS1 的扰动分数: -28.6147
# 正在处理转录因子: LGALS2
#   LGALS2 的扰动分数: -5.0501
# 正在处理转录因子: LGALS3
#   LGALS3 的扰动分数: -30.4399
# 正在处理转录因子: LILRB1
#   LILRB1 的扰动分数: -2.7783
# 正在处理转录因子: LILRB2
#   LILRB2 的扰动分数: -6.2706
# 正在处理转录因子: LILRB3
#   LILRB3 的扰动分数: -9.4473
# 正在处理转录因子: LMNA
#   LMNA 的扰动分数: -22.9761
# 正在处理转录因子: LMO4
#   LMO4 的扰动分数: -4.5537
# 正在处理转录因子: LPAR6
#   LPAR6 的扰动分数: 0.5094
# 正在处理转录因子: LPL
#   LPL 的扰动分数: 15.6878
# 正在处理转录因子: LRP1
#   LRP1 的扰动分数: -11.7891
# 正在处理转录因子: LRRK2
#   LRRK2 的扰动分数: -33.7224
# 正在处理转录因子: LTB
#   LTB 的扰动分数: -2.7042
# 正在处理转录因子: LTF
#   LTF 的扰动分数: 0.0997
# 正在处理转录因子: LY96
#   LY96 的扰动分数: -20.5935
# 正在处理转录因子: LYST
#   LYST 的扰动分数: -26.8733
# 正在处理转录因子: LYZ
#   LYZ 的扰动分数: -68.2963
# 正在处理转录因子: LZTFL1
#   LZTFL1 的扰动分数: 5.3671
# 正在处理转录因子: MAF
#   MAF 的扰动分数: -3.9061
# 正在处理转录因子: MAFB
#   MAFB 的扰动分数: -23.7668
# 正在处理转录因子: MAFF
#   MAFF 的扰动分数: -19.3394
# 正在处理转录因子: MAL
#   MAL 的扰动分数: -0.3897
# 正在处理转录因子: MALT1
#   MALT1 的扰动分数: -2.6943
# 正在处理转录因子: MAML2
#   MAML2 的扰动分数: -0.0879
# 正在处理转录因子: MAP1A
#   MAP1A 的扰动分数: 3.7485
# 正在处理转录因子: MAP2
#   MAP2 的扰动分数: 0.2008
# 正在处理转录因子: MAP2K6
#   MAP2K6 的扰动分数: -0.4927
# 正在处理转录因子: MAP3K21
#   MAP3K21 的扰动分数: 0.8885
# 正在处理转录因子: MAP3K8
#   MAP3K8 的扰动分数: -15.5179
# 正在处理转录因子: MAP4K4
#   MAP4K4 的扰动分数: -7.8256
# 正在处理转录因子: MAPK13
#   MAPK13 的扰动分数: 0.0046
# 正在处理转录因子: MARCO
#   MARCO 的扰动分数: -14.5813
# 正在处理转录因子: MAST4
#   MAST4 的扰动分数: 4.7525
# 正在处理转录因子: MDM2
#   MDM2 的扰动分数: -20.1882
# 正在处理转录因子: MECOM
#   MECOM 的扰动分数: 7.1300
# 正在处理转录因子: MGAM
#   MGAM 的扰动分数: -0.0938
# 正在处理转录因子: MKI67
#   MKI67 的扰动分数: 2.0816
# 正在处理转录因子: MLH3
#   MLH3 的扰动分数: 4.9658
# 正在处理转录因子: MME
#   MME 的扰动分数: 1.7529
# 正在处理转录因子: MMP7
#   MMP7 的扰动分数: 5.1027
# 正在处理转录因子: MNDA
#   MNDA 的扰动分数: -61.3017
# 正在处理转录因子: MOCS2
#   MOCS2 的扰动分数: 2.7389
# 正在处理转录因子: MPO
#   MPO 的扰动分数: 18.5114
# 正在处理转录因子: MS4A1
#   MS4A1 的扰动分数: -0.0903
# 正在处理转录因子: MS4A2
#   MS4A2 的扰动分数: 1.1453
# 正在处理转录因子: MS4A3
#   MS4A3 的扰动分数: -0.4633
# 正在处理转录因子: MS4A7
#   MS4A7 的扰动分数: -14.3402
# 正在处理转录因子: MT1M
#   MT1M 的扰动分数: 1.2170
# 正在处理转录因子: MT2A
#   MT2A 的扰动分数: -9.8020
# 正在处理转录因子: MTF1
#   MTF1 的扰动分数: -13.0392
# 正在处理转录因子: MTUS1
#   MTUS1 的扰动分数: 4.0655
# 正在处理转录因子: MX1
#   MX1 的扰动分数: -3.0926
# 正在处理转录因子: MX2
#   MX2 的扰动分数: -11.5624
# 正在处理转录因子: MYBL1
#   MYBL1 的扰动分数: -2.8662
# 正在处理转录因子: MYC
#   MYC 的扰动分数: 58.2261
# 正在处理转录因子: MYLK
#   MYLK 的扰动分数: 1.2916
# 正在处理转录因子: MYO5A
#   MYO5A 的扰动分数: -7.5125
# 正在处理转录因子: NAMPT
#   NAMPT 的扰动分数: -29.0465
# 正在处理转录因子: NAV3
#   NAV3 的扰动分数: 0.2813
# 正在处理转录因子: NCF1
#   NCF1 的扰动分数: -14.3210
# 正在处理转录因子: NCF2
#   NCF2 的扰动分数: -45.2310
# 正在处理转录因子: NCK2
#   NCK2 的扰动分数: 4.3644
# 正在处理转录因子: NEAT1
#   NEAT1 的扰动分数: -6.0341
# 正在处理转录因子: NEDD9
#   NEDD9 的扰动分数: -3.1125
# 正在处理转录因子: NEUROD1
#   NEUROD1 的扰动分数: 0.2800
# 正在处理转录因子: NEUROD2
#   NEUROD2 的扰动分数: 4.3539
# 正在处理转录因子: NFATC2
#   NFATC2 的扰动分数: 1.3177
# 正在处理转录因子: NFKB2
#   NFKB2 的扰动分数: -2.2894
# 正在处理转录因子: NFKBIA
#   NFKBIA 的扰动分数: -37.1828
# 正在处理转录因子: NOS3
#   NOS3 的扰动分数: 0.6436
# 正在处理转录因子: NOTCH1
#   NOTCH1 的扰动分数: 0.8685
# 正在处理转录因子: NPAT
#   NPAT 的扰动分数: 4.4347
# 正在处理转录因子: NPTX2
#   NPTX2 的扰动分数: -2.9132
# 正在处理转录因子: NQO1
#   NQO1 的扰动分数: 2.1581
# 正在处理转录因子: NR2F2
#   NR2F2 的扰动分数: 0.0263
# 正在处理转录因子: NR3C2
#   NR3C2 的扰动分数: 0.3773
# 正在处理转录因子: NR4A1
#   NR4A1 的扰动分数: 0.3812
# 正在处理转录因子: NR4A2
#   NR4A2 的扰动分数: 5.2176
# 正在处理转录因子: NRG1
#   NRG1 的扰动分数: -0.9848
# 正在处理转录因子: NRIP1
#   NRIP1 的扰动分数: 6.1227
# 正在处理转录因子: NSG1
#   NSG1 的扰动分数: 0.4285
# 正在处理转录因子: NTRK2
#   NTRK2 的扰动分数: 0.1107
# 正在处理转录因子: NTS
#   NTS 的扰动分数: 0.0088
# 正在处理转录因子: NUSAP1
#   NUSAP1 的扰动分数: -0.9410
# 正在处理转录因子: OAS1
#   OAS1 的扰动分数: -0.6114
# 正在处理转录因子: OAS2
#   OAS2 的扰动分数: -0.1922
# 正在处理转录因子: OPTN
#   OPTN 的扰动分数: -1.7500
# 正在处理转录因子: OSM
#   OSM 的扰动分数: -8.8547
# 正在处理转录因子: OSMR
#   OSMR 的扰动分数: 0.6703
# 正在处理转录因子: P2RY13
#   P2RY13 的扰动分数: -4.2668
# 正在处理转录因子: P2RY14
#   P2RY14 的扰动分数: 0.7328
# 正在处理转录因子: PADI4
#   PADI4 的扰动分数: 0.8814
# 正在处理转录因子: PAG1
#   PAG1 的扰动分数: -5.2571
# 正在处理转录因子: PALLD
#   PALLD 的扰动分数: -3.7045
# 正在处理转录因子: PAPPA
#   PAPPA 的扰动分数: 0.3218
# 正在处理转录因子: PAX5
#   PAX5 的扰动分数: 0.6962
# 正在处理转录因子: PAX6
#   PAX6 的扰动分数: 0.9820
# 正在处理转录因子: PBX1
#   PBX1 的扰动分数: 4.3431
# 正在处理转录因子: PCDH8
#   PCDH8 的扰动分数: 0.0548
# 正在处理转录因子: PCED1B
#   PCED1B 的扰动分数: -0.2015
# 正在处理转录因子: PCGF5
#   PCGF5 的扰动分数: -1.2853
# 正在处理转录因子: PDE4B
#   PDE4B 的扰动分数: 7.5893
# 正在处理转录因子: PDE4D
#   PDE4D 的扰动分数: -7.2878
# 正在处理转录因子: PDE8A
#   PDE8A 的扰动分数: -0.2467
# 正在处理转录因子: PDGFA
#   PDGFA 的扰动分数: 0.8278
# 正在处理转录因子: PDK1
#   PDK1 的扰动分数: -4.9722
# 正在处理转录因子: PDK4
#   PDK4 的扰动分数: -5.9565
# 正在处理转录因子: PDPK1
#   PDPK1 的扰动分数: -0.4648
# 正在处理转录因子: PELI1
#   PELI1 的扰动分数: -4.5422
# 正在处理转录因子: PEX1
#   PEX1 的扰动分数: -2.2635
# 正在处理转录因子: PFKFB3
#   PFKFB3 的扰动分数: -4.8922
# 正在处理转录因子: PGAP1
#   PGAP1 的扰动分数: 0.8013
# 正在处理转录因子: PHLDB2
#   PHLDB2 的扰动分数: 0.8363
# 正在处理转录因子: PIK3C2B
#   PIK3C2B 的扰动分数: 1.5418
# 正在处理转录因子: PIK3CA
#   PIK3CA 的扰动分数: -5.6537
# 正在处理转录因子: PIM2
#   PIM2 的扰动分数: -1.2233
# 正在处理转录因子: PITX1
#   PITX1 的扰动分数: 0.2874
# 正在处理转录因子: PLAG1
#   PLAG1 的扰动分数: 0.7595
# 正在处理转录因子: PLAT
#   PLAT 的扰动分数: 0.2248
# 正在处理转录因子: PLAUR
#   PLAUR 的扰动分数: -16.4114
# 正在处理转录因子: PLBD1
#   PLBD1 的扰动分数: -12.3080
# 正在处理转录因子: PLK2
#   PLK2 的扰动分数: -0.0087
# 正在处理转录因子: PMAIP1
#   PMAIP1 的扰动分数: -1.9268
# 正在处理转录因子: POLR3G
#   POLR3G 的扰动分数: 1.8767
# 正在处理转录因子: POU2AF1
#   POU2AF1 的扰动分数: 0.3729
# 正在处理转录因子: POU2F2
#   POU2F2 的扰动分数: -36.7066
# 正在处理转录因子: POU4F1
#   POU4F1 的扰动分数: 0.9929
# 正在处理转录因子: PPARD
#   PPARD 的扰动分数: -3.8872
# 正在处理转录因子: PPARGC1A
#   PPARGC1A 的扰动分数: -2.6328
# 正在处理转录因子: PPP1R2
#   PPP1R2 的扰动分数: -4.4131
# 正在处理转录因子: PRAME
#   PRAME 的扰动分数: 8.2855
# 正在处理转录因子: PRDM1
#   PRDM1 的扰动分数: 2.1741
# 正在处理转录因子: PRDM5
#   PRDM5 的扰动分数: 0.2338
# 正在处理转录因子: PRF1
#   PRF1 的扰动分数: -2.1191
# 正在处理转录因子: PRKAB2
#   PRKAB2 的扰动分数: 1.5924
# 正在处理转录因子: PRKAG2
#   PRKAG2 的扰动分数: -0.1548
# 正在处理转录因子: PRKCE
#   PRKCE 的扰动分数: 0.4848
# 正在处理转录因子: PRKG2
#   PRKG2 的扰动分数: 1.9659
# 正在处理转录因子: PRLR
#   PRLR 的扰动分数: -8.7670
# 正在处理转录因子: PRTN3
#   PRTN3 的扰动分数: 14.8352
# 正在处理转录因子: PTCH1
#   PTCH1 的扰动分数: 0.0378
# 正在处理转录因子: PTGDS
#   PTGDS 的扰动分数: 1.0747
# 正在处理转录因子: PTGS2
#   PTGS2 的扰动分数: -12.8699
# 正在处理转录因子: PTPRJ
#   PTPRJ 的扰动分数: -4.0499
# 正在处理转录因子: PTS
#   PTS 的扰动分数: -0.5629
# 正在处理转录因子: PURA
#   PURA 的扰动分数: -0.0468
# 正在处理转录因子: RAB8B
#   RAB8B 的扰动分数: -4.5085
# 正在处理转录因子: RAF1
#   RAF1 的扰动分数: -2.7153
# 正在处理转录因子: RAG1
#   RAG1 的扰动分数: 0.4808
# 正在处理转录因子: RAG2
#   RAG2 的扰动分数: 0.1614
# 正在处理转录因子: RALGPS2
#   RALGPS2 的扰动分数: 3.0112
# 正在处理转录因子: RAP2A
#   RAP2A 的扰动分数: 0.4017
# 正在处理转录因子: RAPGEF6
#   RAPGEF6 的扰动分数: 7.8972
# 正在处理转录因子: RASA2
#   RASA2 的扰动分数: -6.2188
# 正在处理转录因子: RASSF5
#   RASSF5 的扰动分数: -8.1102
# 正在处理转录因子: RBBP5
#   RBBP5 的扰动分数: 16.9818
# 正在处理转录因子: RBM47
#   RBM47 的扰动分数: -5.1093
# 正在处理转录因子: RBPJ
#   RBPJ 的扰动分数: -10.3126
# 正在处理转录因子: RECK
#   RECK 的扰动分数: -2.7634
# 正在处理转录因子: REL
#   REL 的扰动分数: -26.4701
# 正在处理转录因子: RETN
#   RETN 的扰动分数: -26.7044
# 正在处理转录因子: RGS1
#   RGS1 的扰动分数: -0.5015
# 正在处理转录因子: RGS16
#   RGS16 的扰动分数: 0.9935
# 正在处理转录因子: RGS2
#   RGS2 的扰动分数: -32.6068
# 正在处理转录因子: RGS7
#   RGS7 的扰动分数: 0.0518
# 正在处理转录因子: RHAG
#   RHAG 的扰动分数: -0.3603
# 正在处理转录因子: RHOB
#   RHOB 的扰动分数: -4.6409
# 正在处理转录因子: RHOH
#   RHOH 的扰动分数: 1.6748
# 正在处理转录因子: RICTOR
#   RICTOR 的扰动分数: -0.0820
# 正在处理转录因子: RIT1
#   RIT1 的扰动分数: -3.4318
# 正在处理转录因子: RORA
#   RORA 的扰动分数: -4.1538
# 正在处理转录因子: RORC
#   RORC 的扰动分数: 0.1647
# 正在处理转录因子: RPS3A
#   RPS3A 的扰动分数: 16.5264
# 正在处理转录因子: RPS6
#   RPS6 的扰动分数: 17.3895
# 正在处理转录因子: RPS6KA5
#   RPS6KA5 的扰动分数: -3.0763
# 正在处理转录因子: RUNX1T1
#   RUNX1T1 的扰动分数: 0.8761
# 正在处理转录因子: RUNX3
#   RUNX3 的扰动分数: -9.4807
# 正在处理转录因子: RXRA
#   RXRA 的扰动分数: -40.8063
# 正在处理转录因子: RYK
#   RYK 的扰动分数: 1.2120
# 正在处理转录因子: S100A10
#   S100A10 的扰动分数: -38.4814
# 正在处理转录因子: S100A12
#   S100A12 的扰动分数: 2.7965
# 正在处理转录因子: S100A8
#   S100A8 的扰动分数: -67.4583
# 正在处理转录因子: S100A9
#   S100A9 的扰动分数: -67.9341
# 正在处理转录因子: S100B
#   S100B 的扰动分数: 1.5765
# 正在处理转录因子: S1PR1
#   S1PR1 的扰动分数: -0.5758
# 正在处理转录因子: S1PR5
#   S1PR5 的扰动分数: -0.0001
# 正在处理转录因子: SACS
#   SACS 的扰动分数: 4.2082
# 正在处理转录因子: SAMD9L
#   SAMD9L 的扰动分数: -5.9568
# 正在处理转录因子: SAMHD1
#   SAMHD1 的扰动分数: -21.6875
# 正在处理转录因子: SAMSN1
#   SAMSN1 的扰动分数: -22.4500
# 正在处理转录因子: SAP30
#   SAP30 的扰动分数: -26.4043
# 正在处理转录因子: SAT1
#   SAT1 的扰动分数: -32.1996
# 正在处理转录因子: SDC1
#   SDC1 的扰动分数: 0.3515
# 正在处理转录因子: SEL1L
#   SEL1L 的扰动分数: -1.3187
# 正在处理转录因子: SELP
#   SELP 的扰动分数: 1.2181
# 正在处理转录因子: SERPINA1
#   SERPINA1 的扰动分数: -6.5287
# 正在处理转录因子: SERPINB2
#   SERPINB2 的扰动分数: -4.3778
# 正在处理转录因子: SERPINE1
#   SERPINE1 的扰动分数: 0.5319
# 正在处理转录因子: SGK1
#   SGK1 的扰动分数: -5.9505
# 正在处理转录因子: SGPL1
#   SGPL1 的扰动分数: 0.5287
# 正在处理转录因子: SGPP1
#   SGPP1 的扰动分数: 0.4729
# 正在处理转录因子: SH2D1A
#   SH2D1A 的扰动分数: 1.5325
# 正在处理转录因子: SH2D1B
#   SH2D1B 的扰动分数: 0.2767
# 正在处理转录因子: SH3BP5
#   SH3BP5 的扰动分数: -6.7822
# 正在处理转录因子: SIGLEC6
#   SIGLEC6 的扰动分数: 1.5136
# 正在处理转录因子: SIRT1
#   SIRT1 的扰动分数: -4.7072
# 正在处理转录因子: SKIL
#   SKIL 的扰动分数: -10.9831
# 正在处理转录因子: SLA
#   SLA 的扰动分数: -8.6568
# 正在处理转录因子: SLAMF1
#   SLAMF1 的扰动分数: -0.2382
# 正在处理转录因子: SLAMF6
#   SLAMF6 的扰动分数: -0.0173
# 正在处理转录因子: SLAMF7
#   SLAMF7 的扰动分数: 0.7274
# 正在处理转录因子: SLC11A1
#   SLC11A1 的扰动分数: -4.0717
# 正在处理转录因子: SLC1A3
#   SLC1A3 的扰动分数: -1.5214
# 正在处理转录因子: SLC22A23
#   SLC22A23 的扰动分数: 0.5533
# 正在处理转录因子: SLC22A3
#   SLC22A3 的扰动分数: 0.1187
# 正在处理转录因子: SLC24A4
#   SLC24A4 的扰动分数: -13.8572
# 正在处理转录因子: SLC2A4
#   SLC2A4 的扰动分数: -11.0999
# 正在处理转录因子: SLC40A1
#   SLC40A1 的扰动分数: 7.3093
# 正在处理转录因子: SLC4A1
#   SLC4A1 的扰动分数: -0.5758
# 正在处理转录因子: SLC4A10
#   SLC4A10 的扰动分数: 0.3837
# 正在处理转录因子: SLC4A1AP
#   SLC4A1AP 的扰动分数: 5.2369
# 正在处理转录因子: SLC7A7
#   SLC7A7 的扰动分数: -12.5676
# 正在处理转录因子: SLC8A1
#   SLC8A1 的扰动分数: -18.4398
# 正在处理转录因子: SLCO2A1
#   SLCO2A1 的扰动分数: 0.0809
# 正在处理转录因子: SLPI
#   SLPI 的扰动分数: -2.7150
# 正在处理转录因子: SMAD3
#   SMAD3 的扰动分数: -9.8138
# 正在处理转录因子: SMAD7
#   SMAD7 的扰动分数: 0.2164
# 正在处理转录因子: SMARCA1
#   SMARCA1 的扰动分数: 2.6152
# 正在处理转录因子: SNCA
#   SNCA 的扰动分数: 12.0189
# 正在处理转录因子: SNX9
#   SNX9 的扰动分数: 1.0682
# 正在处理转录因子: SOCS2
#   SOCS2 的扰动分数: 5.0820
# 正在处理转录因子: SORBS1
#   SORBS1 的扰动分数: 0.3833
# 正在处理转录因子: SOX5
#   SOX5 的扰动分数: 0.0614
# 正在处理转录因子: SP4
#   SP4 的扰动分数: -0.4399
# 正在处理转录因子: SPAST
#   SPAST 的扰动分数: -0.0356
# 正在处理转录因子: SPIB
#   SPIB 的扰动分数: 0.9237
# 正在处理转录因子: SPP1
#   SPP1 的扰动分数: 0.4765
# 正在处理转录因子: SPTA1
#   SPTA1 的扰动分数: 0.3070
# 正在处理转录因子: SPTAN1
#   SPTAN1 的扰动分数: 0.5655
# 正在处理转录因子: SRGN
#   SRGN 的扰动分数: -48.7589
# 正在处理转录因子: SSR4
#   SSR4 的扰动分数: 18.8521
# 正在处理转录因子: SSX2IP
#   SSX2IP 的扰动分数: 0.3230
# 正在处理转录因子: STAMBPL1
#   STAMBPL1 的扰动分数: 0.8999
# 正在处理转录因子: STAP1
#   STAP1 的扰动分数: 3.8295
# 正在处理转录因子: STAT1
#   STAT1 的扰动分数: -49.5822
# 正在处理转录因子: STAT4
#   STAT4 的扰动分数: 0.7735
# 正在处理转录因子: STK17A
#   STK17A 的扰动分数: -4.9818
# 正在处理转录因子: SYAP1
#   SYAP1 的扰动分数: -5.0146
# 正在处理转录因子: SYNE1
#   SYNE1 的扰动分数: -2.7020
# 正在处理转录因子: SYNE2
#   SYNE2 的扰动分数: -5.5365
# 正在处理转录因子: TADA3
#   TADA3 的扰动分数: 0.3135
# 正在处理转录因子: TAF9B
#   TAF9B 的扰动分数: 1.1731
# 正在处理转录因子: TBC1D4
#   TBC1D4 的扰动分数: 0.0070
# 正在处理转录因子: TBL1X
#   TBL1X 的扰动分数: -5.1776
# 正在处理转录因子: TBX21
#   TBX21 的扰动分数: -3.3780
# 正在处理转录因子: TCAF1
#   TCAF1 的扰动分数: 3.1571
# 正在处理转录因子: TCF4
#   TCF4 的扰动分数: 39.8544
# 正在处理转录因子: TCF7
#   TCF7 的扰动分数: -2.8229
# 正在处理转录因子: TCHP
#   TCHP 的扰动分数: 0.8603
# 正在处理转录因子: TCL1A
#   TCL1A 的扰动分数: 0.2863
# 正在处理转录因子: TDRD3
#   TDRD3 的扰动分数: 1.3399
# 正在处理转录因子: TEAD1
#   TEAD1 的扰动分数: 0.1449
# 正在处理转录因子: TF
#   TF 的扰动分数: 0.1146
# 正在处理转录因子: TFPI
#   TFPI 的扰动分数: 8.7667
# 正在处理转录因子: TFRC
#   TFRC 的扰动分数: 12.7765
# 正在处理转录因子: TGFBR1
#   TGFBR1 的扰动分数: -7.7658
# 正在处理转录因子: TGFBR2
#   TGFBR2 的扰动分数: -9.2682
# 正在处理转录因子: THBS1
#   THBS1 的扰动分数: 0.5580
# 正在处理转录因子: THRB
#   THRB 的扰动分数: -6.5393
# 正在处理转录因子: TLE1
#   TLE1 的扰动分数: -0.9048
# 正在处理转录因子: TLR4
#   TLR4 的扰动分数: -25.2451
# 正在处理转录因子: TLR5
#   TLR5 的扰动分数: -2.0358
# 正在处理转录因子: TLR8
#   TLR8 的扰动分数: -14.2178
# 正在处理转录因子: TMPRSS11D
#   TMPRSS11D 的扰动分数: 0.0544
# 正在处理转录因子: TMSB4X
#   TMSB4X 的扰动分数: -30.5798
# 正在处理转录因子: TNC
#   TNC 的扰动分数: 0.3718
# 正在处理转录因子: TNF
#   TNF 的扰动分数: -28.3686
# 正在处理转录因子: TNFAIP2
#   TNFAIP2 的扰动分数: -13.0670
# 正在处理转录因子: TNFAIP3
#   TNFAIP3 的扰动分数: -21.8709
# 正在处理转录因子: TNFRSF13B
#   TNFRSF13B 的扰动分数: 0.4259
# 正在处理转录因子: TNFRSF17
#   TNFRSF17 的扰动分数: 0.3899
# 正在处理转录因子: TNFRSF1B
#   TNFRSF1B 的扰动分数: -22.9894
# 正在处理转录因子: TNFRSF21
#   TNFRSF21 的扰动分数: 1.6295
# 正在处理转录因子: TNFSF10
#   TNFSF10 的扰动分数: -20.7034
# 正在处理转录因子: TNIK
#   TNIK 的扰动分数: 0.7727
# 正在处理转录因子: TNKS
#   TNKS 的扰动分数: 1.8635
# 正在处理转录因子: TNNI2
#   TNNI2 的扰动分数: 0.0403
# 正在处理转录因子: TNRC6C
#   TNRC6C 的扰动分数: -0.4562
# 正在处理转录因子: TOB1
#   TOB1 的扰动分数: 0.1943
# 正在处理转录因子: TOP2A
#   TOP2A 的扰动分数: -0.7028
# 正在处理转录因子: TOX
#   TOX 的扰动分数: 1.9650
# 正在处理转录因子: TP53INP1
#   TP53INP1 的扰动分数: 0.7888
# 正在处理转录因子: TP53INP2
#   TP53INP2 的扰动分数: 2.4868
# 正在处理转录因子: TPD52
#   TPD52 的扰动分数: 2.8335
# 正在处理转录因子: TPM1
#   TPM1 的扰动分数: 1.8969
# 正在处理转录因子: TPSAB1
#   TPSAB1 的扰动分数: 1.9209
# 正在处理转录因子: TPSB2
#   TPSB2 的扰动分数: 1.4665
# 正在处理转录因子: TRAF1
#   TRAF1 的扰动分数: 0.1888
# 正在处理转录因子: TRAF6
#   TRAF6 的扰动分数: -3.3924
# 正在处理转录因子: TRAT1
#   TRAT1 的扰动分数: -2.4227
# 正在处理转录因子: TREM1
#   TREM1 的扰动分数: -14.5954
# 正在处理转录因子: TRH
#   TRH 的扰动分数: 5.2898
# 正在处理转录因子: TRIB2
#   TRIB2 的扰动分数: -1.7660
# 正在处理转录因子: TRIM23
#   TRIM23 的扰动分数: 1.5920
# 正在处理转录因子: TRPC1
#   TRPC1 的扰动分数: 0.7050
# 正在处理转录因子: TRPS1
#   TRPS1 的扰动分数: -0.5644
# 正在处理转录因子: TSC22D1
#   TSC22D1 的扰动分数: 5.2907
# 正在处理转录因子: TSLP
#   TSLP 的扰动分数: 0.6224
# 正在处理转录因子: TTN
#   TTN 的扰动分数: -2.1635
# 正在处理转录因子: TUBB1
#   TUBB1 的扰动分数: 0.8555
# 正在处理转录因子: TWISTNB
#   TWISTNB 的扰动分数: 10.4568
# 正在处理转录因子: TXK
#   TXK 的扰动分数: -0.8879
# 正在处理转录因子: TXNDC5
#   TXNDC5 的扰动分数: 1.0351
# 正在处理转录因子: TXNIP
#   TXNIP 的扰动分数: -22.8833
# 正在处理转录因子: TYROBP
#   TYROBP 的扰动分数: -26.2472
# 正在处理转录因子: UACA
#   UACA 的扰动分数: 0.4618
# 正在处理转录因子: UBASH3B
#   UBASH3B 的扰动分数: -4.0432
# 正在处理转录因子: USP28
#   USP28 的扰动分数: 1.5337
# 正在处理转录因子: USP53
#   USP53 的扰动分数: 2.7253
# 正在处理转录因子: UTP15
#   UTP15 的扰动分数: 2.6647
# 正在处理转录因子: VAPB
#   VAPB 的扰动分数: 1.1414
# 正在处理转录因子: VCAM1
#   VCAM1 的扰动分数: 0.1228
# 正在处理转录因子: VCAN
#   VCAN 的扰动分数: -60.9080
# 正在处理转录因子: VIM
#   VIM 的扰动分数: -16.5464
# 正在处理转录因子: VMP1
#   VMP1 的扰动分数: -9.3097
# 正在处理转录因子: VNN1
#   VNN1 的扰动分数: -1.1231
# 正在处理转录因子: WNT10A
#   WNT10A 的扰动分数: 0.2769
# 正在处理转录因子: WWP1
#   WWP1 的扰动分数: -0.7213
# 正在处理转录因子: XAF1
#   XAF1 的扰动分数: -10.5604
# 正在处理转录因子: XCL1
#   XCL1 的扰动分数: 0.0693
# 正在处理转录因子: ZAP70
#   ZAP70 的扰动分数: -1.1035
# 正在处理转录因子: ZBTB16
#   ZBTB16 的扰动分数: 6.5845
# 正在处理转录因子: ZBTB18
#   ZBTB18 的扰动分数: -1.3836
# 正在处理转录因子: ZBTB20
#   ZBTB20 的扰动分数: 3.6309
# 正在处理转录因子: ZBTB40
#   ZBTB40 的扰动分数: 1.1098
# 正在处理转录因子: ZBTB6
#   ZBTB6 的扰动分数: 1.9584
# 正在处理转录因子: ZC3H12A
#   ZC3H12A 的扰动分数: -1.5037
# 正在处理转录因子: ZEB1
#   ZEB1 的扰动分数: 29.1449
# 正在处理转录因子: ZFHX3
#   ZFHX3 的扰动分数: 1.1465
# 正在处理转录因子: ZFYVE16
#   ZFYVE16 的扰动分数: -0.7795
# 正在处理转录因子: ZKSCAN8
#   ZKSCAN8 的扰动分数: 6.0261
# 正在处理转录因子: ZNF143
#   ZNF143 的扰动分数: -24.0048
# 正在处理转录因子: ZNF174
#   ZNF174 的扰动分数: 1.2485
# 正在处理转录因子: ZNF25
#   ZNF25 的扰动分数: -3.4564
# 正在处理转录因子: ZNF704
#   ZNF704 的扰动分数: -3.3360
# 正在处理转录因子: ZNFX1
#   ZNFX1 的扰动分数: 10.6806
#
# 关键TF排序（按扰动分数降序）:
# 1. MYC: 58.2261
# 2. GATA2: 49.4291
# 3. TCF4: 39.8544
# 4. ZEB1: 29.1449
# 5. IL1B: 24.1229
# 6. CD34: 22.6840
# 7. HIST1H4C: 20.5623
# 8. SSR4: 18.8521
# 9. MPO: 18.5114
# 10. RPS6: 17.3895

# %%
# 创建结果DataFrame
results_df = pd.DataFrame(sorted_tfs, columns=['TF', 'Perturbation_Score'])
results_df['Abs_Score'] = np.abs(results_df['Perturbation_Score'])
results_df = results_df.sort_values('Perturbation_Score', ascending=False)
results_df.to_csv("/disk1/cai029/Caufussion/Benchmark_driver/Methods/CellOracle/celloracle_key_biomarkers.csv")

# %%
# 可视化前20个关键TF
plt.figure(figsize=(12, 8))
top_tfs = results_df.head(20)
colors = ['red' if score < 0 else 'green' for score in top_tfs['Perturbation_Score']]

plt.barh(range(len(top_tfs)), top_tfs['Abs_Score'], color=colors, alpha=0.7)
plt.yticks(range(len(top_tfs)), top_tfs['TF'])
plt.xlabel('扰动分数绝对值')
plt.title('Perturbation')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig("/disk1/cai029/Caufussion/Benchmark_driver/Methods/CellOracle/1.png")
plt.show()

# 显示最重要的关键标志物
print("\n=== 疾病进展中最关键的前10个标志物 ===")
for i, row in results_df.head(10).iterrows():
    effect = "促进疾病进展" if row['Perturbation_Score'] > 0 else "抑制疾病进展"
    print(f"{row['TF']}: 扰动分数 = {row['Perturbation_Score']:.4f} ({effect})")
# Out:
# === 疾病进展中最关键的前10个标志物 ===
# MYC: 扰动分数 = 58.2261 (促进疾病进展)
# GATA2: 扰动分数 = 49.4291 (促进疾病进展)
# TCF4: 扰动分数 = 39.8544 (促进疾病进展)
# ZEB1: 扰动分数 = 29.1449 (促进疾病进展)
# IL1B: 扰动分数 = 24.1229 (促进疾病进展)
# CD34: 扰动分数 = 22.6840 (促进疾病进展)
# HIST1H4C: 扰动分数 = 20.5623 (促进疾病进展)
# SSR4: 扰动分数 = 18.8521 (促进疾病进展)
# MPO: 扰动分数 = 18.5114 (促进疾病进展)
# RPS6: 扰动分数 = 17.3895 (促进疾病进展)

# %%
results_df
